# %%
# Enable auto-reloading of external modules - useful during development
# %load_ext autoreload
# %autoreload 2

# Configure Python path to find our custom modules
import sys
from pathlib import Path

# Add project root to the Python path for proper imports
project_root = Path.cwd().parent
if project_root not in sys.path:
    sys.path.insert(0, str(project_root))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import necessary libraries
import src.processing as processing
import src.config as lists

# %%
# Load and process data
df = processing.load_data("/Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/data/raw/nvzfxcoxdvh1at7i.csv")
df_prepared = processing.prepare_data(df)
df_added_features = processing.create_all_model_features_orchestrated(df_prepared)
df_missing = processing.drop_missing_final_vars_streamlined(df_added_features, lists.final_set_A_predictor_names_and_dependent)
df_final = processing.annual_winsorize_variables(df_missing, lists.columns_to_winsorize)
# Out:
# /Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/src/processing.py:42: DtypeWarning: Columns (10,11,12,16,17,22,26,30,33,34,35,945,946,948,949,950,955,969,970,975,980) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# Data loaded successfully from /Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/data/raw/nvzfxcoxdvh1at7i.csv
# Original number of observations: 317304
# Number of columns after selection: 30
# Observations after year filter (2000-2023): 302751
# Observations after excluding financial and utility firms: 170598
# Starting feature construction. Initial df shape: (170598, 30)
#   Creating lags for: ['at', 'ni', 'rect', 'invt', 'ap', 'sale']
#
# Performing pre-calculation validity checks & preparations...
#   Missing 'xrd' values filled with 0.
#   'ipo_year' created from 'ipodate'.
#
# Constructing dependent variable...
#   OCF_Scaled_t_plus_1 created.
#
# Constructing Set A (OLS) predictors...
#   Set A predictors constructed.
#
# Constructing control dummy variables...
#   Dummy variables constructed.
#
# Constructing Set B (additional ML) predictors...
#   Set B predictors constructed.
#
# Selecting final model variables and dropping intermediate columns...
#   Shape of DataFrame after final column selection: (170598, 31)
#   Final columns kept: 31 columns
#
# Feature construction complete. Final DataFrame shape: (170598, 31)
#
# Starting final dropna. Initial rows: 170598, DataFrame shape: (170598, 31)
#   Rows dropped due to NaNs in critical model variables: 47149
#   Shape of analytical sample AFTER final dropna: (123449, 31)
#   Verification: No NaNs in checked columns of analytical sample.
#
# Starting annual winsorization for 22 columns...
#   Winsorizing column: Accruals_Scaled_t
#   Winsorizing column: CAPX_Scaled_t
#   Winsorizing column: CapitalIntensity_t
#   Winsorizing column: CurrentRatio_t
#   Winsorizing column: DP_Scaled_t
#   Winsorizing column: DebtToAssets_t
#   Winsorizing column: Delta_AP_Scaled_t
#   Winsorizing column: Delta_Inv_Scaled_t
#   Winsorizing column: Delta_Rec_Scaled_t
#   Winsorizing column: Delta_Sales_Scaled_t
#   Winsorizing column: GPM_t
#   Winsorizing column: InvTurnover_t
#   Winsorizing column: MkBk_t
#   Winsorizing column: NI_Scaled_Lag_t
#   Winsorizing column: NI_Scaled_t
#   Winsorizing column: OCF_Scaled_Lag_t
#   Winsorizing column: OCF_Scaled_t_plus_1
#   Winsorizing column: OCFtoSales_t
#   Winsorizing column: RecTurnover_t
#   Winsorizing column: XRD_Scaled_t
#   Winsorizing column: XSGA_Scaled_t
#   Winsorizing column: ln_at_t
# Annual winsorization complete.

# %%
# Split data chronologically - train on pre-2018, test on 2018+
train_df, test_df = processing.split_data_chronologically(df_final, 'fyear', split_year=2018)

print(f"Training data shape: {train_df.shape}")
print(f"Test data shape: {test_df.shape}")
print(f"Training period: {train_df['fyear'].min()} - {train_df['fyear'].max()}")
print(f"Test period: {test_df['fyear'].min()} - {test_df['fyear'].max()}")
# Out:
# Training set: 102567 obs (Predictor years <= 2018)
# Test set: 20882 obs (Predictor years > 2018)
# Training data shape: (102567, 31)
# Test data shape: (20882, 31)
# Training period: 2001.0 - 2018.0
# Test period: 2019.0 - 2022.0

# %%
# Set B (Additional ML) predictor feature names
SET_B_FEATURES = [
    'XSGA_Scaled_t', 'XRD_Scaled_t', 'CAPX_Scaled_t', 'CurrentRatio_t',
    'DebtToAssets_t', 'OCFtoSales_t', 'InvTurnover_t', 'RecTurnover_t',
    'GPM_t', 'Delta_Sales_Scaled_t', 'NI_Scaled_Lag_t',
    'CapitalIntensity_t', 'MkBk_t', 'FirmAge_t'
]

# Prepare features and dependent variable for XGBoost regression
# Using SET_A + SET_B + dummy controls to show the full power of ML
X_train = train_df[lists.SET_A_FEATURES + lists.SET_B_FEATURES + lists.OLS_DUMMY_FEATURES_FINAL]
y_train = train_df[lists.DEPENDENT_VARIABLE]

X_test = test_df[lists.SET_A_FEATURES + lists.SET_B_FEATURES + lists.OLS_DUMMY_FEATURES_FINAL]
y_test = test_df[lists.DEPENDENT_VARIABLE]

print("Features included in the model:")
for i, feature in enumerate(X_train.columns, 1):
    print(f"{i:2d}. {feature}")

print(f"\nDependent variable: {lists.DEPENDENT_VARIABLE}")
print(f"Training observations: {len(X_train)}")
print(f"Test observations: {len(X_test)}")
# Out:
# Features included in the model:
#  1. OCF_Scaled_Lag_t
#  2. NI_Scaled_t
#  3. Accruals_Scaled_t
#  4. Delta_Rec_Scaled_t
#  5. Delta_Inv_Scaled_t
#  6. Delta_AP_Scaled_t
#  7. DP_Scaled_t
#  8. ln_at_t
#  9. XSGA_Scaled_t
# 10. XRD_Scaled_t
# 11. CAPX_Scaled_t
# 12. CurrentRatio_t
# 13. DebtToAssets_t
# 14. OCFtoSales_t
# 15. InvTurnover_t
# 16. RecTurnover_t
# 17. GPM_t
# 18. Delta_Sales_Scaled_t
# 19. NI_Scaled_Lag_t
# 20. CapitalIntensity_t
# 21. MkBk_t
# 22. FirmAge_t
# 23. ASC606_TCJA_combined_dummy
#
# Dependent variable: OCF_Scaled_t_plus_1
# Training observations: 102567
# Test observations: 20882

# %%
# =============================================================================
# BAYESIAN OPTIMIZATION FOR HYPERPARAMETER TUNING
# =============================================================================

import xgboost as xgb
from skopt import BayesSearchCV
from skopt.space import Real, Integer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np
import time

# Define hyperparameter search space for Bayesian optimization
search_space = {
    'max_depth': Integer(3, 10),
    'learning_rate': Real(0.01, 0.2, prior='log-uniform'),
    'n_estimators': Integer(100, 300),
    'subsample': Real(0.8, 1.0),
    'colsample_bytree': Real(0.8, 1.0)
}

# Create XGBoost regressor
xgb_regressor = xgb.XGBRegressor(random_state=42, objective='reg:squarederror')

# Perform Bayesian Search with 5-fold cross-validation
print("Performing 5-fold cross-validation for XGBoost Bayesian hyperparameter tuning...")
print(f"Search space dimensions: {len(search_space)}")
print(f"Number of iterations: 100 (intelligent sampling)")

start_time = time.time()

bayes_search = BayesSearchCV(
    estimator=xgb_regressor,
    search_spaces=search_space,
    n_iter=100,  # Number of parameter settings to try
    cv=5,
    scoring='r2',
    n_jobs=-1,
    random_state=42,
    verbose=2  # Increased verbosity for more detailed progress information
)

# Fit the bayesian search
bayes_search.fit(X_train, y_train)

# Print best parameters and score
print(f"\nBest hyperparameters: {bayes_search.best_params_}")
print(f"Best cross-validation R² score: {bayes_search.best_score_:.4f}")
print(f"Standard deviation: {bayes_search.cv_results_['std_test_score'][bayes_search.best_index_]:.4f}")

elapsed_time = time.time() - start_time
print(f"Bayesian search completed in {elapsed_time:.2f} seconds")

# For compatibility with rest of the code, assign to grid_search variable
grid_search = bayes_search
# Out:
# Performing 5-fold cross-validation for XGBoost Bayesian hyperparameter tuning...
# Search space dimensions: 5
# Number of iterations: 100 (intelligent sampling)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   8.6s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   8.8s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   8.9s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   8.9s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   9.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   3.5s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   3.5s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   3.5s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   3.0s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   3.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   2.5s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   2.6s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   2.7s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   2.7s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=  10.8s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=  10.8s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=  10.9s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=  10.9s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=  11.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=  10.7s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=  10.6s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=  10.8s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=  10.8s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=  10.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   3.1s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   3.1s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   3.3s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   3.3s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   3.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   8.5s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   8.5s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   8.7s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   8.6s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   8.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   7.6s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   7.6s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   7.6s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   7.6s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   7.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  15.6s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  15.8s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  15.9s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  16.0s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  16.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   6.7s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   6.7s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   6.8s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   6.8s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   6.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8955393318425259, learning_rate=0.021971188957164114, max_depth=5, n_estimators=270, subsample=0.9949708367325472; total time=   5.2s
# [CV] END colsample_bytree=0.8955393318425259, learning_rate=0.021971188957164114, max_depth=5, n_estimators=270, subsample=0.9949708367325472; total time=   5.2s
# [CV] END colsample_bytree=0.8955393318425259, learning_rate=0.021971188957164114, max_depth=5, n_estimators=270, subsample=0.9949708367325472; total time=   5.3s
# [CV] END colsample_bytree=0.8955393318425259, learning_rate=0.021971188957164114, max_depth=5, n_estimators=270, subsample=0.9949708367325472; total time=   5.4s
# [CV] END colsample_bytree=0.8955393318425259, learning_rate=0.021971188957164114, max_depth=5, n_estimators=270, subsample=0.9949708367325472; total time=   5.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9145425643678158, learning_rate=0.0194638212021663, max_depth=3, n_estimators=221, subsample=0.9372396677239733; total time=   2.7s
# [CV] END colsample_bytree=0.9145425643678158, learning_rate=0.0194638212021663, max_depth=3, n_estimators=221, subsample=0.9372396677239733; total time=   2.7s
# [CV] END colsample_bytree=0.9145425643678158, learning_rate=0.0194638212021663, max_depth=3, n_estimators=221, subsample=0.9372396677239733; total time=   2.7s
# [CV] END colsample_bytree=0.9145425643678158, learning_rate=0.0194638212021663, max_depth=3, n_estimators=221, subsample=0.9372396677239733; total time=   2.7s
# [CV] END colsample_bytree=0.9145425643678158, learning_rate=0.0194638212021663, max_depth=3, n_estimators=221, subsample=0.9372396677239733; total time=   2.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9380181749956817, learning_rate=0.0245894005999294, max_depth=10, n_estimators=281, subsample=0.8941600096097588; total time=  26.7s
# [CV] END colsample_bytree=0.9380181749956817, learning_rate=0.0245894005999294, max_depth=10, n_estimators=281, subsample=0.8941600096097588; total time=  26.9s
# [CV] END colsample_bytree=0.9380181749956817, learning_rate=0.0245894005999294, max_depth=10, n_estimators=281, subsample=0.8941600096097588; total time=  27.1s
# [CV] END colsample_bytree=0.9380181749956817, learning_rate=0.0245894005999294, max_depth=10, n_estimators=281, subsample=0.8941600096097588; total time=  27.1s
# [CV] END colsample_bytree=0.9380181749956817, learning_rate=0.0245894005999294, max_depth=10, n_estimators=281, subsample=0.8941600096097588; total time=  27.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9740436370124148, learning_rate=0.016340670613440196, max_depth=5, n_estimators=290, subsample=0.9208307060470374; total time=   4.7s
# [CV] END colsample_bytree=0.9740436370124148, learning_rate=0.016340670613440196, max_depth=5, n_estimators=290, subsample=0.9208307060470374; total time=   4.7s
# [CV] END colsample_bytree=0.9740436370124148, learning_rate=0.016340670613440196, max_depth=5, n_estimators=290, subsample=0.9208307060470374; total time=   4.7s
# [CV] END colsample_bytree=0.9740436370124148, learning_rate=0.016340670613440196, max_depth=5, n_estimators=290, subsample=0.9208307060470374; total time=   4.7s
# [CV] END colsample_bytree=0.9740436370124148, learning_rate=0.016340670613440196, max_depth=5, n_estimators=290, subsample=0.9208307060470374; total time=   4.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9780367097437644, learning_rate=0.029658229257768263, max_depth=5, n_estimators=300, subsample=0.9565037251580446; total time=   5.2s
# [CV] END colsample_bytree=0.9780367097437644, learning_rate=0.029658229257768263, max_depth=5, n_estimators=300, subsample=0.9565037251580446; total time=   5.2s
# [CV] END colsample_bytree=0.9780367097437644, learning_rate=0.029658229257768263, max_depth=5, n_estimators=300, subsample=0.9565037251580446; total time=   5.2s
# [CV] END colsample_bytree=0.9780367097437644, learning_rate=0.029658229257768263, max_depth=5, n_estimators=300, subsample=0.9565037251580446; total time=   5.2s
# [CV] END colsample_bytree=0.9780367097437644, learning_rate=0.029658229257768263, max_depth=5, n_estimators=300, subsample=0.9565037251580446; total time=   5.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8551482050152381, learning_rate=0.01597400032706126, max_depth=6, n_estimators=128, subsample=0.807752622908578; total time=   3.4s
# [CV] END colsample_bytree=0.8551482050152381, learning_rate=0.01597400032706126, max_depth=6, n_estimators=128, subsample=0.807752622908578; total time=   3.4s
# [CV] END colsample_bytree=0.8551482050152381, learning_rate=0.01597400032706126, max_depth=6, n_estimators=128, subsample=0.807752622908578; total time=   3.5s
# [CV] END colsample_bytree=0.8551482050152381, learning_rate=0.01597400032706126, max_depth=6, n_estimators=128, subsample=0.807752622908578; total time=   3.5s
# [CV] END colsample_bytree=0.8551482050152381, learning_rate=0.01597400032706126, max_depth=6, n_estimators=128, subsample=0.807752622908578; total time=   3.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.833348177576869, learning_rate=0.054224132524905176, max_depth=3, n_estimators=292, subsample=0.9853588727675656; total time=   3.7s
# [CV] END colsample_bytree=0.833348177576869, learning_rate=0.054224132524905176, max_depth=3, n_estimators=292, subsample=0.9853588727675656; total time=   3.7s
# [CV] END colsample_bytree=0.833348177576869, learning_rate=0.054224132524905176, max_depth=3, n_estimators=292, subsample=0.9853588727675656; total time=   3.6s
# [CV] END colsample_bytree=0.833348177576869, learning_rate=0.054224132524905176, max_depth=3, n_estimators=292, subsample=0.9853588727675656; total time=   3.7s
# [CV] END colsample_bytree=0.833348177576869, learning_rate=0.054224132524905176, max_depth=3, n_estimators=292, subsample=0.9853588727675656; total time=   3.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9738374630514022, learning_rate=0.08188659408927525, max_depth=3, n_estimators=100, subsample=0.8015414828120141; total time=   1.4s
# [CV] END colsample_bytree=0.9738374630514022, learning_rate=0.08188659408927525, max_depth=3, n_estimators=100, subsample=0.8015414828120141; total time=   1.5s
# [CV] END colsample_bytree=0.9738374630514022, learning_rate=0.08188659408927525, max_depth=3, n_estimators=100, subsample=0.8015414828120141; total time=   1.6s
# [CV] END colsample_bytree=0.9738374630514022, learning_rate=0.08188659408927525, max_depth=3, n_estimators=100, subsample=0.8015414828120141; total time=   1.6s
# [CV] END colsample_bytree=0.9738374630514022, learning_rate=0.08188659408927525, max_depth=3, n_estimators=100, subsample=0.8015414828120141; total time=   1.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8107184066874907, learning_rate=0.028032102680260747, max_depth=3, n_estimators=300, subsample=0.8698049848571981; total time=   3.0s
# [CV] END colsample_bytree=0.8107184066874907, learning_rate=0.028032102680260747, max_depth=3, n_estimators=300, subsample=0.8698049848571981; total time=   3.0s
# [CV] END colsample_bytree=0.8107184066874907, learning_rate=0.028032102680260747, max_depth=3, n_estimators=300, subsample=0.8698049848571981; total time=   3.0s
# [CV] END colsample_bytree=0.8107184066874907, learning_rate=0.028032102680260747, max_depth=3, n_estimators=300, subsample=0.8698049848571981; total time=   3.0s
# [CV] END colsample_bytree=0.8107184066874907, learning_rate=0.028032102680260747, max_depth=3, n_estimators=300, subsample=0.8698049848571981; total time=   3.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8584663463579602, learning_rate=0.01, max_depth=8, n_estimators=300, subsample=1.0; total time=  18.5s
# [CV] END colsample_bytree=0.8584663463579602, learning_rate=0.01, max_depth=8, n_estimators=300, subsample=1.0; total time=  18.8s
# [CV] END colsample_bytree=0.8584663463579602, learning_rate=0.01, max_depth=8, n_estimators=300, subsample=1.0; total time=  18.8s
# [CV] END colsample_bytree=0.8584663463579602, learning_rate=0.01, max_depth=8, n_estimators=300, subsample=1.0; total time=  19.1s
# [CV] END colsample_bytree=0.8584663463579602, learning_rate=0.01, max_depth=8, n_estimators=300, subsample=1.0; total time=  19.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8719840995875551, learning_rate=0.022845990283306583, max_depth=7, n_estimators=300, subsample=0.8764812045200961; total time=  10.2s
# [CV] END colsample_bytree=0.8719840995875551, learning_rate=0.022845990283306583, max_depth=7, n_estimators=300, subsample=0.8764812045200961; total time=  10.2s
# [CV] END colsample_bytree=0.8719840995875551, learning_rate=0.022845990283306583, max_depth=7, n_estimators=300, subsample=0.8764812045200961; total time=  10.5s
# [CV] END colsample_bytree=0.8719840995875551, learning_rate=0.022845990283306583, max_depth=7, n_estimators=300, subsample=0.8764812045200961; total time=  10.5s
# [CV] END colsample_bytree=0.8719840995875551, learning_rate=0.022845990283306583, max_depth=7, n_estimators=300, subsample=0.8764812045200961; total time=  10.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9755895302281739, learning_rate=0.06780531645892308, max_depth=3, n_estimators=216, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.9755895302281739, learning_rate=0.06780531645892308, max_depth=3, n_estimators=216, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.9755895302281739, learning_rate=0.06780531645892308, max_depth=3, n_estimators=216, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.9755895302281739, learning_rate=0.06780531645892308, max_depth=3, n_estimators=216, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.9755895302281739, learning_rate=0.06780531645892308, max_depth=3, n_estimators=216, subsample=1.0; total time=   2.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9010679684948655, learning_rate=0.021078404221318254, max_depth=6, n_estimators=300, subsample=1.0; total time=   7.7s
# [CV] END colsample_bytree=0.9010679684948655, learning_rate=0.021078404221318254, max_depth=6, n_estimators=300, subsample=1.0; total time=   7.7s
# [CV] END colsample_bytree=0.9010679684948655, learning_rate=0.021078404221318254, max_depth=6, n_estimators=300, subsample=1.0; total time=   7.8s
# [CV] END colsample_bytree=0.9010679684948655, learning_rate=0.021078404221318254, max_depth=6, n_estimators=300, subsample=1.0; total time=   7.8s
# [CV] END colsample_bytree=0.9010679684948655, learning_rate=0.021078404221318254, max_depth=6, n_estimators=300, subsample=1.0; total time=   7.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9858538465165672, learning_rate=0.010544506167986509, max_depth=10, n_estimators=190, subsample=0.8258576784377556; total time=  23.0s
# [CV] END colsample_bytree=0.9858538465165672, learning_rate=0.010544506167986509, max_depth=10, n_estimators=190, subsample=0.8258576784377556; total time=  23.0s
# [CV] END colsample_bytree=0.9858538465165672, learning_rate=0.010544506167986509, max_depth=10, n_estimators=190, subsample=0.8258576784377556; total time=  23.4s
# [CV] END colsample_bytree=0.9858538465165672, learning_rate=0.010544506167986509, max_depth=10, n_estimators=190, subsample=0.8258576784377556; total time=  23.7s
# [CV] END colsample_bytree=0.9858538465165672, learning_rate=0.010544506167986509, max_depth=10, n_estimators=190, subsample=0.8258576784377556; total time=  23.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9553392475804299, learning_rate=0.04376830983073962, max_depth=5, n_estimators=275, subsample=0.9604584639534077; total time=   4.6s
# [CV] END colsample_bytree=0.9553392475804299, learning_rate=0.04376830983073962, max_depth=5, n_estimators=275, subsample=0.9604584639534077; total time=   4.7s
# [CV] END colsample_bytree=0.9553392475804299, learning_rate=0.04376830983073962, max_depth=5, n_estimators=275, subsample=0.9604584639534077; total time=   4.9s
# [CV] END colsample_bytree=0.9553392475804299, learning_rate=0.04376830983073962, max_depth=5, n_estimators=275, subsample=0.9604584639534077; total time=   4.9s
# [CV] END colsample_bytree=0.9553392475804299, learning_rate=0.04376830983073962, max_depth=5, n_estimators=275, subsample=0.9604584639534077; total time=   5.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.981818796114897, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9087604555089793; total time=  12.5s
# [CV] END colsample_bytree=0.981818796114897, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9087604555089793; total time=  12.6s
# [CV] END colsample_bytree=0.981818796114897, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9087604555089793; total time=  12.7s
# [CV] END colsample_bytree=0.981818796114897, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9087604555089793; total time=  12.8s
# [CV] END colsample_bytree=0.981818796114897, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.9087604555089793; total time=  12.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8200902758384426, learning_rate=0.042010503862988026, max_depth=10, n_estimators=100, subsample=0.8060019227652094; total time=  10.3s
# [CV] END colsample_bytree=0.8200902758384426, learning_rate=0.042010503862988026, max_depth=10, n_estimators=100, subsample=0.8060019227652094; total time=  10.3s
# [CV] END colsample_bytree=0.8200902758384426, learning_rate=0.042010503862988026, max_depth=10, n_estimators=100, subsample=0.8060019227652094; total time=  10.5s
# [CV] END colsample_bytree=0.8200902758384426, learning_rate=0.042010503862988026, max_depth=10, n_estimators=100, subsample=0.8060019227652094; total time=  10.4s
# [CV] END colsample_bytree=0.8200902758384426, learning_rate=0.042010503862988026, max_depth=10, n_estimators=100, subsample=0.8060019227652094; total time=  10.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8556198346613242, learning_rate=0.09003467940171866, max_depth=3, n_estimators=157, subsample=0.982502136460137; total time=   1.4s
# [CV] END colsample_bytree=0.8556198346613242, learning_rate=0.09003467940171866, max_depth=3, n_estimators=157, subsample=0.982502136460137; total time=   1.4s
# [CV] END colsample_bytree=0.8556198346613242, learning_rate=0.09003467940171866, max_depth=3, n_estimators=157, subsample=0.982502136460137; total time=   1.4s
# [CV] END colsample_bytree=0.8556198346613242, learning_rate=0.09003467940171866, max_depth=3, n_estimators=157, subsample=0.982502136460137; total time=   1.3s
# [CV] END colsample_bytree=0.8556198346613242, learning_rate=0.09003467940171866, max_depth=3, n_estimators=157, subsample=0.982502136460137; total time=   1.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8720477852137039, learning_rate=0.0505894950275895, max_depth=5, n_estimators=300, subsample=0.8357237389521655; total time=   4.8s
# [CV] END colsample_bytree=0.8720477852137039, learning_rate=0.0505894950275895, max_depth=5, n_estimators=300, subsample=0.8357237389521655; total time=   4.9s
# [CV] END colsample_bytree=0.8720477852137039, learning_rate=0.0505894950275895, max_depth=5, n_estimators=300, subsample=0.8357237389521655; total time=   4.9s
# [CV] END colsample_bytree=0.8720477852137039, learning_rate=0.0505894950275895, max_depth=5, n_estimators=300, subsample=0.8357237389521655; total time=   4.9s
# [CV] END colsample_bytree=0.8720477852137039, learning_rate=0.0505894950275895, max_depth=5, n_estimators=300, subsample=0.8357237389521655; total time=   4.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9072576396654344, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.983104110173005; total time=   1.2s
# [CV] END colsample_bytree=0.9072576396654344, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.983104110173005; total time=   1.2s
# [CV] END colsample_bytree=0.9072576396654344, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.983104110173005; total time=   1.2s
# [CV] END colsample_bytree=0.9072576396654344, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.983104110173005; total time=   1.2s
# [CV] END colsample_bytree=0.9072576396654344, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.983104110173005; total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.027242759119531057, max_depth=6, n_estimators=280, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.027242759119531057, max_depth=6, n_estimators=280, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.027242759119531057, max_depth=6, n_estimators=280, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.027242759119531057, max_depth=6, n_estimators=280, subsample=0.8; total time=   7.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.027242759119531057, max_depth=6, n_estimators=280, subsample=0.8; total time=   7.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9970922329352631, learning_rate=0.06354096395905517, max_depth=6, n_estimators=102, subsample=0.9149373721025628; total time=   2.7s
# [CV] END colsample_bytree=0.9970922329352631, learning_rate=0.06354096395905517, max_depth=6, n_estimators=102, subsample=0.9149373721025628; total time=   2.7s
# [CV] END colsample_bytree=0.9970922329352631, learning_rate=0.06354096395905517, max_depth=6, n_estimators=102, subsample=0.9149373721025628; total time=   2.7s
# [CV] END colsample_bytree=0.9970922329352631, learning_rate=0.06354096395905517, max_depth=6, n_estimators=102, subsample=0.9149373721025628; total time=   2.8s
# [CV] END colsample_bytree=0.9970922329352631, learning_rate=0.06354096395905517, max_depth=6, n_estimators=102, subsample=0.9149373721025628; total time=   2.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8903872776397734, learning_rate=0.062161584698236634, max_depth=10, n_estimators=300, subsample=0.8381481643433503; total time=  29.6s
# [CV] END colsample_bytree=0.8903872776397734, learning_rate=0.062161584698236634, max_depth=10, n_estimators=300, subsample=0.8381481643433503; total time=  29.8s
# [CV] END colsample_bytree=0.8903872776397734, learning_rate=0.062161584698236634, max_depth=10, n_estimators=300, subsample=0.8381481643433503; total time=  29.8s
# [CV] END colsample_bytree=0.8903872776397734, learning_rate=0.062161584698236634, max_depth=10, n_estimators=300, subsample=0.8381481643433503; total time=  29.8s
# [CV] END colsample_bytree=0.8903872776397734, learning_rate=0.062161584698236634, max_depth=10, n_estimators=300, subsample=0.8381481643433503; total time=  29.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9608856427136008, learning_rate=0.010342106935124828, max_depth=3, n_estimators=291, subsample=0.999605422379957; total time=   2.4s
# [CV] END colsample_bytree=0.9608856427136008, learning_rate=0.010342106935124828, max_depth=3, n_estimators=291, subsample=0.999605422379957; total time=   2.4s
# [CV] END colsample_bytree=0.9608856427136008, learning_rate=0.010342106935124828, max_depth=3, n_estimators=291, subsample=0.999605422379957; total time=   2.6s
# [CV] END colsample_bytree=0.9608856427136008, learning_rate=0.010342106935124828, max_depth=3, n_estimators=291, subsample=0.999605422379957; total time=   2.6s
# [CV] END colsample_bytree=0.9608856427136008, learning_rate=0.010342106935124828, max_depth=3, n_estimators=291, subsample=0.999605422379957; total time=   2.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.804292170109447, learning_rate=0.11372541694299419, max_depth=5, n_estimators=102, subsample=0.9900040395399647; total time=   1.3s
# [CV] END colsample_bytree=0.804292170109447, learning_rate=0.11372541694299419, max_depth=5, n_estimators=102, subsample=0.9900040395399647; total time=   1.3s
# [CV] END colsample_bytree=0.804292170109447, learning_rate=0.11372541694299419, max_depth=5, n_estimators=102, subsample=0.9900040395399647; total time=   1.4s
# [CV] END colsample_bytree=0.804292170109447, learning_rate=0.11372541694299419, max_depth=5, n_estimators=102, subsample=0.9900040395399647; total time=   1.3s
# [CV] END colsample_bytree=0.804292170109447, learning_rate=0.11372541694299419, max_depth=5, n_estimators=102, subsample=0.9900040395399647; total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8276608786851362, learning_rate=0.0452544407202282, max_depth=5, n_estimators=172, subsample=0.9059048767861544; total time=   2.9s
# [CV] END colsample_bytree=0.8276608786851362, learning_rate=0.0452544407202282, max_depth=5, n_estimators=172, subsample=0.9059048767861544; total time=   3.0s
# [CV] END colsample_bytree=0.8276608786851362, learning_rate=0.0452544407202282, max_depth=5, n_estimators=172, subsample=0.9059048767861544; total time=   3.1s
# [CV] END colsample_bytree=0.8276608786851362, learning_rate=0.0452544407202282, max_depth=5, n_estimators=172, subsample=0.9059048767861544; total time=   3.0s
# [CV] END colsample_bytree=0.8276608786851362, learning_rate=0.0452544407202282, max_depth=5, n_estimators=172, subsample=0.9059048767861544; total time=   3.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.06348118655088346, max_depth=5, n_estimators=170, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06348118655088346, max_depth=5, n_estimators=170, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06348118655088346, max_depth=5, n_estimators=170, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06348118655088346, max_depth=5, n_estimators=170, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.06348118655088346, max_depth=5, n_estimators=170, subsample=0.8; total time=   2.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9868930129700421, learning_rate=0.19182590393027804, max_depth=3, n_estimators=289, subsample=0.9677776469139983; total time=   3.3s
# [CV] END colsample_bytree=0.9868930129700421, learning_rate=0.19182590393027804, max_depth=3, n_estimators=289, subsample=0.9677776469139983; total time=   3.3s
# [CV] END colsample_bytree=0.9868930129700421, learning_rate=0.19182590393027804, max_depth=3, n_estimators=289, subsample=0.9677776469139983; total time=   3.3s
# [CV] END colsample_bytree=0.9868930129700421, learning_rate=0.19182590393027804, max_depth=3, n_estimators=289, subsample=0.9677776469139983; total time=   3.4s
# [CV] END colsample_bytree=0.9868930129700421, learning_rate=0.19182590393027804, max_depth=3, n_estimators=289, subsample=0.9677776469139983; total time=   3.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9636980980792904, learning_rate=0.10009238063522881, max_depth=3, n_estimators=295, subsample=0.8194690499013263; total time=   2.5s
# [CV] END colsample_bytree=0.9636980980792904, learning_rate=0.10009238063522881, max_depth=3, n_estimators=295, subsample=0.8194690499013263; total time=   2.6s
# [CV] END colsample_bytree=0.9636980980792904, learning_rate=0.10009238063522881, max_depth=3, n_estimators=295, subsample=0.8194690499013263; total time=   2.6s
# [CV] END colsample_bytree=0.9636980980792904, learning_rate=0.10009238063522881, max_depth=3, n_estimators=295, subsample=0.8194690499013263; total time=   2.6s
# [CV] END colsample_bytree=0.9636980980792904, learning_rate=0.10009238063522881, max_depth=3, n_estimators=295, subsample=0.8194690499013263; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9283598545240722, learning_rate=0.03969827385941098, max_depth=3, n_estimators=101, subsample=0.9104003427060836; total time=   1.0s
# [CV] END colsample_bytree=0.9283598545240722, learning_rate=0.03969827385941098, max_depth=3, n_estimators=101, subsample=0.9104003427060836; total time=   1.0s
# [CV] END colsample_bytree=0.9283598545240722, learning_rate=0.03969827385941098, max_depth=3, n_estimators=101, subsample=0.9104003427060836; total time=   1.0s
# [CV] END colsample_bytree=0.9283598545240722, learning_rate=0.03969827385941098, max_depth=3, n_estimators=101, subsample=0.9104003427060836; total time=   1.0s
# [CV] END colsample_bytree=0.9283598545240722, learning_rate=0.03969827385941098, max_depth=3, n_estimators=101, subsample=0.9104003427060836; total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.037733829127318805, max_depth=4, n_estimators=250, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.037733829127318805, max_depth=4, n_estimators=250, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.037733829127318805, max_depth=4, n_estimators=250, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.037733829127318805, max_depth=4, n_estimators=250, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.037733829127318805, max_depth=4, n_estimators=250, subsample=0.8; total time=   2.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  31.5s
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  31.6s
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  31.8s
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  31.8s
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  31.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8064634474788455, learning_rate=0.03791595251320984, max_depth=8, n_estimators=100, subsample=0.9372480184257508; total time=   3.9s
# [CV] END colsample_bytree=0.8064634474788455, learning_rate=0.03791595251320984, max_depth=8, n_estimators=100, subsample=0.9372480184257508; total time=   4.0s
# [CV] END colsample_bytree=0.8064634474788455, learning_rate=0.03791595251320984, max_depth=8, n_estimators=100, subsample=0.9372480184257508; total time=   4.1s
# [CV] END colsample_bytree=0.8064634474788455, learning_rate=0.03791595251320984, max_depth=8, n_estimators=100, subsample=0.9372480184257508; total time=   4.1s
# [CV] END colsample_bytree=0.8064634474788455, learning_rate=0.03791595251320984, max_depth=8, n_estimators=100, subsample=0.9372480184257508; total time=   4.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8124876234634488, learning_rate=0.013807673134382203, max_depth=10, n_estimators=297, subsample=0.8600563089228951; total time=  28.6s
# [CV] END colsample_bytree=0.8124876234634488, learning_rate=0.013807673134382203, max_depth=10, n_estimators=297, subsample=0.8600563089228951; total time=  29.1s
# [CV] END colsample_bytree=0.8124876234634488, learning_rate=0.013807673134382203, max_depth=10, n_estimators=297, subsample=0.8600563089228951; total time=  29.3s
# [CV] END colsample_bytree=0.8124876234634488, learning_rate=0.013807673134382203, max_depth=10, n_estimators=297, subsample=0.8600563089228951; total time=  29.4s
# [CV] END colsample_bytree=0.8124876234634488, learning_rate=0.013807673134382203, max_depth=10, n_estimators=297, subsample=0.8600563089228951; total time=  29.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.0345060667104923, max_depth=5, n_estimators=219, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.0345060667104923, max_depth=5, n_estimators=219, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.0345060667104923, max_depth=5, n_estimators=219, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.0345060667104923, max_depth=5, n_estimators=219, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.0345060667104923, max_depth=5, n_estimators=219, subsample=1.0; total time=   3.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.024090767672553418, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.024090767672553418, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.024090767672553418, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.024090767672553418, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.024090767672553418, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9293011838749954, learning_rate=0.07378603925511765, max_depth=9, n_estimators=101, subsample=0.9726803258096598; total time=   7.8s
# [CV] END colsample_bytree=0.9293011838749954, learning_rate=0.07378603925511765, max_depth=9, n_estimators=101, subsample=0.9726803258096598; total time=   7.8s
# [CV] END colsample_bytree=0.9293011838749954, learning_rate=0.07378603925511765, max_depth=9, n_estimators=101, subsample=0.9726803258096598; total time=   7.8s
# [CV] END colsample_bytree=0.9293011838749954, learning_rate=0.07378603925511765, max_depth=9, n_estimators=101, subsample=0.9726803258096598; total time=   7.9s
# [CV] END colsample_bytree=0.9293011838749954, learning_rate=0.07378603925511765, max_depth=9, n_estimators=101, subsample=0.9726803258096598; total time=   8.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8078556819906734, learning_rate=0.021803945862098943, max_depth=10, n_estimators=101, subsample=0.924992667091575; total time=  12.2s
# [CV] END colsample_bytree=0.8078556819906734, learning_rate=0.021803945862098943, max_depth=10, n_estimators=101, subsample=0.924992667091575; total time=  12.5s
# [CV] END colsample_bytree=0.8078556819906734, learning_rate=0.021803945862098943, max_depth=10, n_estimators=101, subsample=0.924992667091575; total time=  12.6s
# [CV] END colsample_bytree=0.8078556819906734, learning_rate=0.021803945862098943, max_depth=10, n_estimators=101, subsample=0.924992667091575; total time=  12.6s
# [CV] END colsample_bytree=0.8078556819906734, learning_rate=0.021803945862098943, max_depth=10, n_estimators=101, subsample=0.924992667091575; total time=  12.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9205046377714758, learning_rate=0.1991583385435126, max_depth=6, n_estimators=101, subsample=0.8833194859511699; total time=   2.8s
# [CV] END colsample_bytree=0.9205046377714758, learning_rate=0.1991583385435126, max_depth=6, n_estimators=101, subsample=0.8833194859511699; total time=   2.8s
# [CV] END colsample_bytree=0.9205046377714758, learning_rate=0.1991583385435126, max_depth=6, n_estimators=101, subsample=0.8833194859511699; total time=   2.9s
# [CV] END colsample_bytree=0.9205046377714758, learning_rate=0.1991583385435126, max_depth=6, n_estimators=101, subsample=0.8833194859511699; total time=   2.8s
# [CV] END colsample_bytree=0.9205046377714758, learning_rate=0.1991583385435126, max_depth=6, n_estimators=101, subsample=0.8833194859511699; total time=   2.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.020066289050863537, max_depth=6, n_estimators=300, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.020066289050863537, max_depth=6, n_estimators=300, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.020066289050863537, max_depth=6, n_estimators=300, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.020066289050863537, max_depth=6, n_estimators=300, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.020066289050863537, max_depth=6, n_estimators=300, subsample=0.8; total time=   6.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9913724730191685, learning_rate=0.03798815141070307, max_depth=6, n_estimators=100, subsample=0.9356460632830783; total time=   2.8s
# [CV] END colsample_bytree=0.9913724730191685, learning_rate=0.03798815141070307, max_depth=6, n_estimators=100, subsample=0.9356460632830783; total time=   2.9s
# [CV] END colsample_bytree=0.9913724730191685, learning_rate=0.03798815141070307, max_depth=6, n_estimators=100, subsample=0.9356460632830783; total time=   2.8s
# [CV] END colsample_bytree=0.9913724730191685, learning_rate=0.03798815141070307, max_depth=6, n_estimators=100, subsample=0.9356460632830783; total time=   3.0s
# [CV] END colsample_bytree=0.9913724730191685, learning_rate=0.03798815141070307, max_depth=6, n_estimators=100, subsample=0.9356460632830783; total time=   3.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9739822299632869, learning_rate=0.010206403414927265, max_depth=3, n_estimators=114, subsample=0.9439878788007989; total time=   1.1s
# [CV] END colsample_bytree=0.9739822299632869, learning_rate=0.010206403414927265, max_depth=3, n_estimators=114, subsample=0.9439878788007989; total time=   1.1s
# [CV] END colsample_bytree=0.9739822299632869, learning_rate=0.010206403414927265, max_depth=3, n_estimators=114, subsample=0.9439878788007989; total time=   1.1s
# [CV] END colsample_bytree=0.9739822299632869, learning_rate=0.010206403414927265, max_depth=3, n_estimators=114, subsample=0.9439878788007989; total time=   1.1s
# [CV] END colsample_bytree=0.9739822299632869, learning_rate=0.010206403414927265, max_depth=3, n_estimators=114, subsample=0.9439878788007989; total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.028487522740475762, max_depth=6, n_estimators=168, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.028487522740475762, max_depth=6, n_estimators=168, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.028487522740475762, max_depth=6, n_estimators=168, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.028487522740475762, max_depth=6, n_estimators=168, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.028487522740475762, max_depth=6, n_estimators=168, subsample=0.8; total time=   3.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8002130905061432, learning_rate=0.03241237456578899, max_depth=10, n_estimators=169, subsample=0.9665556108450399; total time=  17.5s
# [CV] END colsample_bytree=0.8002130905061432, learning_rate=0.03241237456578899, max_depth=10, n_estimators=169, subsample=0.9665556108450399; total time=  17.7s
# [CV] END colsample_bytree=0.8002130905061432, learning_rate=0.03241237456578899, max_depth=10, n_estimators=169, subsample=0.9665556108450399; total time=  17.9s
# [CV] END colsample_bytree=0.8002130905061432, learning_rate=0.03241237456578899, max_depth=10, n_estimators=169, subsample=0.9665556108450399; total time=  18.0s
# [CV] END colsample_bytree=0.8002130905061432, learning_rate=0.03241237456578899, max_depth=10, n_estimators=169, subsample=0.9665556108450399; total time=  18.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8359719813737617, learning_rate=0.190851113765639, max_depth=3, n_estimators=197, subsample=0.9820532146381911; total time=   1.7s
# [CV] END colsample_bytree=0.8359719813737617, learning_rate=0.190851113765639, max_depth=3, n_estimators=197, subsample=0.9820532146381911; total time=   1.8s
# [CV] END colsample_bytree=0.8359719813737617, learning_rate=0.190851113765639, max_depth=3, n_estimators=197, subsample=0.9820532146381911; total time=   1.8s
# [CV] END colsample_bytree=0.8359719813737617, learning_rate=0.190851113765639, max_depth=3, n_estimators=197, subsample=0.9820532146381911; total time=   1.8s
# [CV] END colsample_bytree=0.8359719813737617, learning_rate=0.190851113765639, max_depth=3, n_estimators=197, subsample=0.9820532146381911; total time=   1.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8131986674364121, learning_rate=0.010644448609346683, max_depth=6, n_estimators=238, subsample=0.8110473356141971; total time=   6.0s
# [CV] END colsample_bytree=0.8131986674364121, learning_rate=0.010644448609346683, max_depth=6, n_estimators=238, subsample=0.8110473356141971; total time=   6.0s
# [CV] END colsample_bytree=0.8131986674364121, learning_rate=0.010644448609346683, max_depth=6, n_estimators=238, subsample=0.8110473356141971; total time=   6.1s
# [CV] END colsample_bytree=0.8131986674364121, learning_rate=0.010644448609346683, max_depth=6, n_estimators=238, subsample=0.8110473356141971; total time=   6.2s
# [CV] END colsample_bytree=0.8131986674364121, learning_rate=0.010644448609346683, max_depth=6, n_estimators=238, subsample=0.8110473356141971; total time=   6.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.049991599558889696, max_depth=5, n_estimators=128, subsample=1.0; total time=   7.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.049991599558889696, max_depth=5, n_estimators=128, subsample=1.0; total time=   7.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.049991599558889696, max_depth=5, n_estimators=128, subsample=1.0; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.049991599558889696, max_depth=5, n_estimators=128, subsample=1.0; total time=   7.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.049991599558889696, max_depth=5, n_estimators=128, subsample=1.0; total time=   7.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# ...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.02390791601855987, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.02390791601855987, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.02390791601855987, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.02390791601855987, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.02390791601855987, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.024156950960402854, max_depth=5, n_estimators=289, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.024156950960402854, max_depth=5, n_estimators=289, subsample=0.8; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.024156950960402854, max_depth=5, n_estimators=289, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.024156950960402854, max_depth=5, n_estimators=289, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.024156950960402854, max_depth=5, n_estimators=289, subsample=0.8; total time=   6.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9807444916080812, learning_rate=0.013884523249902843, max_depth=9, n_estimators=296, subsample=0.8040661098707713; total time=  24.2s
# [CV] END colsample_bytree=0.9807444916080812, learning_rate=0.013884523249902843, max_depth=9, n_estimators=296, subsample=0.8040661098707713; total time=  24.4s
# [CV] END colsample_bytree=0.9807444916080812, learning_rate=0.013884523249902843, max_depth=9, n_estimators=296, subsample=0.8040661098707713; total time=  24.4s
# [CV] END colsample_bytree=0.9807444916080812, learning_rate=0.013884523249902843, max_depth=9, n_estimators=296, subsample=0.8040661098707713; total time=  24.6s
# [CV] END colsample_bytree=0.9807444916080812, learning_rate=0.013884523249902843, max_depth=9, n_estimators=296, subsample=0.8040661098707713; total time=  24.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8194134614225685, learning_rate=0.07399800538061503, max_depth=4, n_estimators=280, subsample=0.9883222923092114; total time=   3.1s
# [CV] END colsample_bytree=0.8194134614225685, learning_rate=0.07399800538061503, max_depth=4, n_estimators=280, subsample=0.9883222923092114; total time=   3.1s
# [CV] END colsample_bytree=0.8194134614225685, learning_rate=0.07399800538061503, max_depth=4, n_estimators=280, subsample=0.9883222923092114; total time=   3.2s
# [CV] END colsample_bytree=0.8194134614225685, learning_rate=0.07399800538061503, max_depth=4, n_estimators=280, subsample=0.9883222923092114; total time=   3.2s
# [CV] END colsample_bytree=0.8194134614225685, learning_rate=0.07399800538061503, max_depth=4, n_estimators=280, subsample=0.9883222923092114; total time=   3.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8190830724997374, learning_rate=0.09619362931864066, max_depth=10, n_estimators=252, subsample=0.9065317152787182; total time=  26.1s
# [CV] END colsample_bytree=0.8190830724997374, learning_rate=0.09619362931864066, max_depth=10, n_estimators=252, subsample=0.9065317152787182; total time=  26.1s
# [CV] END colsample_bytree=0.8190830724997374, learning_rate=0.09619362931864066, max_depth=10, n_estimators=252, subsample=0.9065317152787182; total time=  26.2s
# [CV] END colsample_bytree=0.8190830724997374, learning_rate=0.09619362931864066, max_depth=10, n_estimators=252, subsample=0.9065317152787182; total time=  26.3s
# [CV] END colsample_bytree=0.8190830724997374, learning_rate=0.09619362931864066, max_depth=10, n_estimators=252, subsample=0.9065317152787182; total time=  26.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8010489555994863, learning_rate=0.04816528758213665, max_depth=3, n_estimators=160, subsample=0.8000429788566268; total time=   1.3s
# [CV] END colsample_bytree=0.8010489555994863, learning_rate=0.04816528758213665, max_depth=3, n_estimators=160, subsample=0.8000429788566268; total time=   1.3s
# [CV] END colsample_bytree=0.8010489555994863, learning_rate=0.04816528758213665, max_depth=3, n_estimators=160, subsample=0.8000429788566268; total time=   1.3s
# [CV] END colsample_bytree=0.8010489555994863, learning_rate=0.04816528758213665, max_depth=3, n_estimators=160, subsample=0.8000429788566268; total time=   1.3s
# [CV] END colsample_bytree=0.8010489555994863, learning_rate=0.04816528758213665, max_depth=3, n_estimators=160, subsample=0.8000429788566268; total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9716208089272204, learning_rate=0.030276679829646932, max_depth=8, n_estimators=153, subsample=0.8153453114720756; total time=   7.7s
# [CV] END colsample_bytree=0.9716208089272204, learning_rate=0.030276679829646932, max_depth=8, n_estimators=153, subsample=0.8153453114720756; total time=   7.7s
# [CV] END colsample_bytree=0.9716208089272204, learning_rate=0.030276679829646932, max_depth=8, n_estimators=153, subsample=0.8153453114720756; total time=   7.7s
# [CV] END colsample_bytree=0.9716208089272204, learning_rate=0.030276679829646932, max_depth=8, n_estimators=153, subsample=0.8153453114720756; total time=   7.7s
# [CV] END colsample_bytree=0.9716208089272204, learning_rate=0.030276679829646932, max_depth=8, n_estimators=153, subsample=0.8153453114720756; total time=   7.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.02492404024695842, max_depth=5, n_estimators=290, subsample=0.8; total time=   5.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.02492404024695842, max_depth=5, n_estimators=290, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.02492404024695842, max_depth=5, n_estimators=290, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.02492404024695842, max_depth=5, n_estimators=290, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.02492404024695842, max_depth=5, n_estimators=290, subsample=0.8; total time=   5.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.02508590584932023, max_depth=5, n_estimators=283, subsample=0.885092826934338; total time=   4.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.02508590584932023, max_depth=5, n_estimators=283, subsample=0.885092826934338; total time=   5.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.02508590584932023, max_depth=5, n_estimators=283, subsample=0.885092826934338; total time=   5.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.02508590584932023, max_depth=5, n_estimators=283, subsample=0.885092826934338; total time=   5.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.02508590584932023, max_depth=5, n_estimators=283, subsample=0.885092826934338; total time=   5.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8696431730085408, learning_rate=0.10109287276230787, max_depth=10, n_estimators=111, subsample=0.8107499881151997; total time=  11.5s
# [CV] END colsample_bytree=0.8696431730085408, learning_rate=0.10109287276230787, max_depth=10, n_estimators=111, subsample=0.8107499881151997; total time=  11.6s
# [CV] END colsample_bytree=0.8696431730085408, learning_rate=0.10109287276230787, max_depth=10, n_estimators=111, subsample=0.8107499881151997; total time=  11.7s
# [CV] END colsample_bytree=0.8696431730085408, learning_rate=0.10109287276230787, max_depth=10, n_estimators=111, subsample=0.8107499881151997; total time=  11.9s
# [CV] END colsample_bytree=0.8696431730085408, learning_rate=0.10109287276230787, max_depth=10, n_estimators=111, subsample=0.8107499881151997; total time=  12.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.023857204544594068, max_depth=5, n_estimators=288, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.023857204544594068, max_depth=5, n_estimators=288, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.023857204544594068, max_depth=5, n_estimators=288, subsample=0.8; total time=   4.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.023857204544594068, max_depth=5, n_estimators=288, subsample=0.8; total time=   4.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.023857204544594068, max_depth=5, n_estimators=288, subsample=0.8; total time=   5.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.031208732757281813, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.031208732757281813, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.031208732757281813, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.031208732757281813, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.031208732757281813, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.024304717875190195, max_depth=5, n_estimators=285, subsample=0.8636783070301833; total time=   5.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.024304717875190195, max_depth=5, n_estimators=285, subsample=0.8636783070301833; total time=   5.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.024304717875190195, max_depth=5, n_estimators=285, subsample=0.8636783070301833; total time=   5.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.024304717875190195, max_depth=5, n_estimators=285, subsample=0.8636783070301833; total time=   5.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.024304717875190195, max_depth=5, n_estimators=285, subsample=0.8636783070301833; total time=   5.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.024831814251981568, max_depth=5, n_estimators=286, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.024831814251981568, max_depth=5, n_estimators=286, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.024831814251981568, max_depth=5, n_estimators=286, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.024831814251981568, max_depth=5, n_estimators=286, subsample=0.8; total time=   5.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.024831814251981568, max_depth=5, n_estimators=286, subsample=0.8; total time=   5.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9885356552586929, learning_rate=0.018329178834042885, max_depth=6, n_estimators=210, subsample=0.9972397162641469; total time=   6.7s
# [CV] END colsample_bytree=0.9885356552586929, learning_rate=0.018329178834042885, max_depth=6, n_estimators=210, subsample=0.9972397162641469; total time=   6.7s
# [CV] END colsample_bytree=0.9885356552586929, learning_rate=0.018329178834042885, max_depth=6, n_estimators=210, subsample=0.9972397162641469; total time=   6.7s
# [CV] END colsample_bytree=0.9885356552586929, learning_rate=0.018329178834042885, max_depth=6, n_estimators=210, subsample=0.9972397162641469; total time=   6.7s
# [CV] END colsample_bytree=0.9885356552586929, learning_rate=0.018329178834042885, max_depth=6, n_estimators=210, subsample=0.9972397162641469; total time=   6.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8014766883577672, learning_rate=0.010028928558985075, max_depth=10, n_estimators=105, subsample=0.9043780012664627; total time=  14.8s
# [CV] END colsample_bytree=0.8014766883577672, learning_rate=0.010028928558985075, max_depth=10, n_estimators=105, subsample=0.9043780012664627; total time=  15.1s
# [CV] END colsample_bytree=0.8014766883577672, learning_rate=0.010028928558985075, max_depth=10, n_estimators=105, subsample=0.9043780012664627; total time=  15.1s
# [CV] END colsample_bytree=0.8014766883577672, learning_rate=0.010028928558985075, max_depth=10, n_estimators=105, subsample=0.9043780012664627; total time=  15.3s
# [CV] END colsample_bytree=0.8014766883577672, learning_rate=0.010028928558985075, max_depth=10, n_estimators=105, subsample=0.9043780012664627; total time=  15.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.025420428189614628, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.025420428189614628, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.025420428189614628, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.025420428189614628, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.025420428189614628, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.025500248949900908, max_depth=5, n_estimators=300, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.025500248949900908, max_depth=5, n_estimators=300, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.025500248949900908, max_depth=5, n_estimators=300, subsample=0.8; total time=   4.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.025500248949900908, max_depth=5, n_estimators=300, subsample=0.8; total time=   4.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.025500248949900908, max_depth=5, n_estimators=300, subsample=0.8; total time=   4.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.02520925149700464, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.02520925149700464, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.02520925149700464, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.02520925149700464, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.02520925149700464, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.04330778577701506, max_depth=5, n_estimators=193, subsample=1.0; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.04330778577701506, max_depth=5, n_estimators=193, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.04330778577701506, max_depth=5, n_estimators=193, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.04330778577701506, max_depth=5, n_estimators=193, subsample=1.0; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.04330778577701506, max_depth=5, n_estimators=193, subsample=1.0; total time=   2.8s
#
# Best hyperparameters: OrderedDict({'colsample_bytree': 0.8, 'learning_rate': 0.02520925149700464, 'max_depth': 5, 'n_estimators': 300, 'subsample': 0.8})
# Best cross-validation R² score: 0.7255
# Standard deviation: 0.0326
# Bayesian search completed in 1011.98 seconds

# %%
# =============================================================================
# XGBOOST MODEL - For ML Model Comparisons
# =============================================================================

# Use the best model from grid search
best_xgb_model = grid_search.best_estimator_

# Predictions
y_train_pred = best_xgb_model.predict(X_train)
y_test_pred = best_xgb_model.predict(X_test)

# Simple metrics function for any model
def print_model_performance(y_true, y_pred, model_name, dataset):
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    print(f"{model_name} ({dataset}): R²={r2:.4f} | RMSE={rmse:.4f} | MAE={mae:.4f}")

# Print results
print("XGBOOST PERFORMANCE (SET A + SET B FEATURES):")
print_model_performance(y_train, y_train_pred, "XGBoost", "Train")
print_model_performance(y_test, y_test_pred, "XGBoost", "Test")
# Out:
# XGBOOST PERFORMANCE (SET A + SET B FEATURES):
# XGBoost (Train): R²=0.8162 | RMSE=0.4544 | MAE=0.1564
# XGBoost (Test): R²=0.6871 | RMSE=0.5456 | MAE=0.1866

# %%
# =============================================================================
# FEATURE IMPORTANCE ANALYSIS
# =============================================================================

import pandas as pd

# Get feature importances
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': best_xgb_model.feature_importances_
}).sort_values('importance', ascending=False)

print("FEATURE IMPORTANCE RANKING (SET A + SET B FEATURES):")
print("="*50)
for i, (_, row) in enumerate(feature_importance.iterrows(), 1):
    print(f"{i:2d}. {row['feature']:<25} {row['importance']:.4f}")

# Print model details
print(f"\nMODEL DETAILS:")
print(f"Max Depth: {best_xgb_model.max_depth}")
print(f"Learning Rate: {best_xgb_model.learning_rate}")
print(f"N Estimators: {best_xgb_model.n_estimators}")
print(f"Subsample: {best_xgb_model.subsample}")
print(f"Colsample Bytree: {best_xgb_model.colsample_bytree}")
print(f"Number of Features: {best_xgb_model.n_features_in_}")
# Out:
# FEATURE IMPORTANCE RANKING (SET A + SET B FEATURES):
# ==================================================
#  1. NI_Scaled_t               0.3751
#  2. XSGA_Scaled_t             0.1489
#  3. ln_at_t                   0.0768
#  4. OCF_Scaled_Lag_t          0.0763
#  5. OCFtoSales_t              0.0336
#  6. DebtToAssets_t            0.0304
#  7. ASC606_TCJA_combined_dummy 0.0297
#  8. XRD_Scaled_t              0.0256
#  9. MkBk_t                    0.0186
# 10. Accruals_Scaled_t         0.0178
# 11. Delta_AP_Scaled_t         0.0174
# 12. InvTurnover_t             0.0161
# 13. NI_Scaled_Lag_t           0.0156
# 14. CapitalIntensity_t        0.0132
# 15. RecTurnover_t             0.0131
# 16. CurrentRatio_t            0.0131
# 17. FirmAge_t                 0.0127
# 18. GPM_t                     0.0123
# 19. Delta_Sales_Scaled_t      0.0119
# 20. Delta_Rec_Scaled_t        0.0117
# 21. DP_Scaled_t               0.0114
# 22. CAPX_Scaled_t             0.0093
# 23. Delta_Inv_Scaled_t        0.0092
#
# MODEL DETAILS:
# Max Depth: 5
# Learning Rate: 0.02520925149700464
# N Estimators: 300
# Subsample: 0.8
# Colsample Bytree: 0.8
# Number of Features: 23
