# %%
# Enable auto-reloading of external modules - useful during development
# %load_ext autoreload
# %autoreload 2

# Configure Python path to find our custom modules
import sys
from pathlib import Path

# Add project root to the Python path for proper imports
project_root = Path.cwd().parent
if project_root not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
# Import necessary libraries
import src.processing as processing
import src.config as lists

# %%
# Load and process data
df = processing.load_data("/Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/data/raw/nvzfxcoxdvh1at7i.csv")
df_prepared = processing.prepare_data(df)
df_added_features = processing.create_all_model_features_orchestrated(df_prepared)
df_missing = processing.drop_missing_final_vars_streamlined(df_added_features, lists.final_set_A_predictor_names_and_dependent)
df_final = processing.annual_winsorize_variables(df_missing, lists.columns_to_winsorize)
# Out:
# /Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/src/processing.py:42: DtypeWarning: Columns (10,11,12,16,17,22,26,30,33,34,35,945,946,948,949,950,955,969,970,975,980) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# Data loaded successfully from /Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/data/raw/nvzfxcoxdvh1at7i.csv
# Original number of observations: 317304
# Number of columns after selection: 30
# Observations after year filter (2000-2023): 302751
# Observations after excluding financial and utility firms: 170598
# Starting feature construction. Initial df shape: (170598, 30)
#   Creating lags for: ['at', 'ni', 'rect', 'invt', 'ap', 'sale']
#
# Performing pre-calculation validity checks & preparations...
#   Missing 'xrd' values filled with 0.
#   'ipo_year' created from 'ipodate'.
#
# Constructing dependent variable...
#   OCF_Scaled_t_plus_1 created.
#
# Constructing Set A (OLS) predictors...
#   Set A predictors constructed.
#
# Constructing control dummy variables...
#   Dummy variables constructed.
#
# Constructing Set B (additional ML) predictors...
#   Set B predictors constructed.
#
# Selecting final model variables and dropping intermediate columns...
#   Shape of DataFrame after final column selection: (170598, 30)
#   Final columns kept: 30 columns
#
# Feature construction complete. Final DataFrame shape: (170598, 30)
#
# Starting final dropna. Initial rows: 170598, DataFrame shape: (170598, 30)
#   Rows dropped due to NaNs in critical model variables: 47149
#   Shape of analytical sample AFTER final dropna: (123449, 30)
#   Verification: No NaNs in checked columns of analytical sample.
#
# Starting annual winsorization for 22 columns...
#   Winsorizing column: Accruals_Scaled_t
#   Winsorizing column: CAPX_Scaled_t
#   Winsorizing column: CapitalIntensity_t
#   Winsorizing column: CurrentRatio_t
#   Winsorizing column: DP_Scaled_t
#   Winsorizing column: DebtToAssets_t
#   Winsorizing column: Delta_AP_Scaled_t
#   Winsorizing column: Delta_Inv_Scaled_t
#   Winsorizing column: Delta_Rec_Scaled_t
#   Winsorizing column: Delta_Sales_Scaled_t
#   Winsorizing column: GPM_t
#   Winsorizing column: InvTurnover_t
#   Winsorizing column: MkBk_t
#   Winsorizing column: NI_Scaled_Lag_t
#   Winsorizing column: NI_Scaled_t
#   Winsorizing column: OCF_Scaled_Lag_t
#   Winsorizing column: OCF_Scaled_t_plus_1
#   Winsorizing column: OCFtoSales_t
#   Winsorizing column: RecTurnover_t
#   Winsorizing column: XRD_Scaled_t
#   Winsorizing column: XSGA_Scaled_t
#   Winsorizing column: ln_at_t
# Annual winsorization complete.

# %%
# Split data chronologically - train on pre-2018, test on 2018+
train_df, test_df = processing.split_data_chronologically(df_final, 'fyear', split_year=2018)

print(f"Training data shape: {train_df.shape}")
print(f"Test data shape: {test_df.shape}")
print(f"Training period: {train_df['fyear'].min()} - {train_df['fyear'].max()}")
print(f"Test period: {test_df['fyear'].min()} - {test_df['fyear'].max()}")
# Out:
# Training set: 102567 obs (Predictor years <= 2018)
# Test set: 20882 obs (Predictor years > 2018)
# Training data shape: (102567, 30)
# Test data shape: (20882, 30)
# Training period: 2001.0 - 2018.0
# Test period: 2019.0 - 2022.0

# %%
# Set B (Additional ML) predictor feature names
SET_B_FEATURES = [
    'XSGA_Scaled_t', 'XRD_Scaled_t', 'CAPX_Scaled_t', 'CurrentRatio_t',
    'DebtToAssets_t', 'OCFtoSales_t', 'InvTurnover_t', 'RecTurnover_t',
    'GPM_t', 'Delta_Sales_Scaled_t', 'NI_Scaled_Lag_t',
    'CapitalIntensity_t', 'MkBk_t', 'FirmAge_t'
]

# Prepare features and dependent variable for XGBoost regression
# Using SET_A + SET_B + dummy controls to show the full power of ML
X_train = train_df[lists.SET_A_FEATURES + SET_B_FEATURES + lists.CONTROL_DUMMY_FEATURES]
y_train = train_df[lists.DEPENDENT_VARIABLE]

X_test = test_df[lists.SET_A_FEATURES + SET_B_FEATURES + lists.CONTROL_DUMMY_FEATURES]
y_test = test_df[lists.DEPENDENT_VARIABLE]

# Drop dummy variables that caused multicollinearity in OLS
X_train = X_train.drop(columns=['ASC842_dummy', 'COVID_dummy'])
X_test = X_test.drop(columns=['ASC842_dummy', 'COVID_dummy'])

print("Features included in the model:")
for i, feature in enumerate(X_train.columns, 1):
    print(f"{i:2d}. {feature}")

print(f"\nDependent variable: {lists.DEPENDENT_VARIABLE}")
print(f"Training observations: {len(X_train)}")
print(f"Test observations: {len(X_test)}")
# Out:
# Features included in the model:
#  1. OCF_Scaled_Lag_t
#  2. NI_Scaled_t
#  3. Accruals_Scaled_t
#  4. Delta_Rec_Scaled_t
#  5. Delta_Inv_Scaled_t
#  6. Delta_AP_Scaled_t
#  7. DP_Scaled_t
#  8. ln_at_t
#  9. XSGA_Scaled_t
# 10. XRD_Scaled_t
# 11. CAPX_Scaled_t
# 12. CurrentRatio_t
# 13. DebtToAssets_t
# 14. OCFtoSales_t
# 15. InvTurnover_t
# 16. RecTurnover_t
# 17. GPM_t
# 18. Delta_Sales_Scaled_t
# 19. NI_Scaled_Lag_t
# 20. CapitalIntensity_t
# 21. MkBk_t
# 22. FirmAge_t
# 23. ASC606_dummy
# 24. TCJA_dummy
#
# Dependent variable: OCF_Scaled_t_plus_1
# Training observations: 102567
# Test observations: 20882

# %%
# =============================================================================
# BAYESIAN OPTIMIZATION FOR HYPERPARAMETER TUNING
# =============================================================================

import xgboost as xgb
from skopt import BayesSearchCV
from skopt.space import Real, Integer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np
import time

# Define hyperparameter search space for Bayesian optimization
search_space = {
    'max_depth': Integer(3, 10),
    'learning_rate': Real(0.01, 0.2, prior='log-uniform'),
    'n_estimators': Integer(100, 300),
    'subsample': Real(0.8, 1.0),
    'colsample_bytree': Real(0.8, 1.0)
}

# Create XGBoost regressor
xgb_regressor = xgb.XGBRegressor(random_state=42, objective='reg:squarederror')

# Perform Bayesian Search with 5-fold cross-validation
print("Performing 5-fold cross-validation for XGBoost Bayesian hyperparameter tuning...")
print(f"Search space dimensions: {len(search_space)}")
print(f"Number of iterations: 100 (intelligent sampling)")

start_time = time.time()

bayes_search = BayesSearchCV(
    estimator=xgb_regressor,
    search_spaces=search_space,
    n_iter=100,  # Number of parameter settings to try
    cv=5,
    scoring='r2',
    n_jobs=-1,
    random_state=42,
    verbose=2  # Increased verbosity for more detailed progress information
)

# Fit the bayesian search
bayes_search.fit(X_train, y_train)

# Print best parameters and score
print(f"\nBest hyperparameters: {bayes_search.best_params_}")
print(f"Best cross-validation R² score: {bayes_search.best_score_:.4f}")
print(f"Standard deviation: {bayes_search.cv_results_['std_test_score'][bayes_search.best_index_]:.4f}")

elapsed_time = time.time() - start_time
print(f"Bayesian search completed in {elapsed_time:.2f} seconds")

# For compatibility with rest of the code, assign to grid_search variable
grid_search = bayes_search
# Out:
# Performing 5-fold cross-validation for XGBoost Bayesian hyperparameter tuning...
# Search space dimensions: 5
# Number of iterations: 100 (intelligent sampling)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   5.8s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   6.0s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   6.0s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   6.0s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   6.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.8s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.8s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.8s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.7s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   0.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.9s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   4.0s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   4.0s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.9s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   4.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   3.5s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   3.5s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   3.6s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   3.6s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   3.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.1s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.1s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.1s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.1s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.7s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.7s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.7s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.7s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   2.5s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   2.6s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   2.6s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   2.6s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   5.5s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   5.6s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   5.6s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   5.6s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   5.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   3.4s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   3.4s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   3.5s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   3.5s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   3.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=  17.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=  17.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=  17.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=  17.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=  18.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   5.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   5.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=228, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=228, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=228, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=228, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=228, subsample=1.0; total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.025880707863757787, max_depth=3, n_estimators=300, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.025880707863757787, max_depth=3, n_estimators=300, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.025880707863757787, max_depth=3, n_estimators=300, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.025880707863757787, max_depth=3, n_estimators=300, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.025880707863757787, max_depth=3, n_estimators=300, subsample=0.8; total time=   1.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.02588951241629839, max_depth=10, n_estimators=274, subsample=1.0; total time=  11.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.02588951241629839, max_depth=10, n_estimators=274, subsample=1.0; total time=  11.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.02588951241629839, max_depth=10, n_estimators=274, subsample=1.0; total time=  11.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.02588951241629839, max_depth=10, n_estimators=274, subsample=1.0; total time=  12.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.02588951241629839, max_depth=10, n_estimators=274, subsample=1.0; total time=  12.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=158, subsample=0.8248338278259042; total time=   7.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=158, subsample=0.8248338278259042; total time=   7.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=158, subsample=0.8248338278259042; total time=   7.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=158, subsample=0.8248338278259042; total time=   7.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=158, subsample=0.8248338278259042; total time=   8.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.07771938256068514, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.07771938256068514, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.07771938256068514, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.07771938256068514, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.07771938256068514, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.021490850927987814, max_depth=3, n_estimators=262, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.021490850927987814, max_depth=3, n_estimators=262, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.021490850927987814, max_depth=3, n_estimators=262, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.021490850927987814, max_depth=3, n_estimators=262, subsample=1.0; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.021490850927987814, max_depth=3, n_estimators=262, subsample=1.0; total time=   1.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.14570058469855235, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.14570058469855235, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.14570058469855235, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.14570058469855235, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.14570058469855235, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.019874833289830925, max_depth=6, n_estimators=300, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.019874833289830925, max_depth=6, n_estimators=300, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.019874833289830925, max_depth=6, n_estimators=300, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.019874833289830925, max_depth=6, n_estimators=300, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.019874833289830925, max_depth=6, n_estimators=300, subsample=0.8; total time=   3.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.1034850034589574, max_depth=3, n_estimators=143, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1034850034589574, max_depth=3, n_estimators=143, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1034850034589574, max_depth=3, n_estimators=143, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1034850034589574, max_depth=3, n_estimators=143, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1034850034589574, max_depth=3, n_estimators=143, subsample=1.0; total time=   0.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.010064565049084572, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.010064565049084572, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.010064565049084572, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.010064565049084572, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.010064565049084572, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9750851925174104, learning_rate=0.044991084872493384, max_depth=10, n_estimators=113, subsample=0.8887435811554555; total time=   6.1s
# [CV] END colsample_bytree=0.9750851925174104, learning_rate=0.044991084872493384, max_depth=10, n_estimators=113, subsample=0.8887435811554555; total time=   6.2s
# [CV] END colsample_bytree=0.9750851925174104, learning_rate=0.044991084872493384, max_depth=10, n_estimators=113, subsample=0.8887435811554555; total time=   6.3s
# [CV] END colsample_bytree=0.9750851925174104, learning_rate=0.044991084872493384, max_depth=10, n_estimators=113, subsample=0.8887435811554555; total time=   6.3s
# [CV] END colsample_bytree=0.9750851925174104, learning_rate=0.044991084872493384, max_depth=10, n_estimators=113, subsample=0.8887435811554555; total time=   6.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.023670403450437087, max_depth=10, n_estimators=195, subsample=0.8; total time=  10.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.023670403450437087, max_depth=10, n_estimators=195, subsample=0.8; total time=  11.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.023670403450437087, max_depth=10, n_estimators=195, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.023670403450437087, max_depth=10, n_estimators=195, subsample=0.8; total time=  11.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.023670403450437087, max_depth=10, n_estimators=195, subsample=0.8; total time=  11.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.027783590763688804, max_depth=6, n_estimators=300, subsample=1.0; total time=   3.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.027783590763688804, max_depth=6, n_estimators=300, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.027783590763688804, max_depth=6, n_estimators=300, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.027783590763688804, max_depth=6, n_estimators=300, subsample=1.0; total time=   4.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.027783590763688804, max_depth=6, n_estimators=300, subsample=1.0; total time=   4.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8058782310228364, learning_rate=0.06413563546997798, max_depth=3, n_estimators=159, subsample=0.8484712814602339; total time=   1.0s
# [CV] END colsample_bytree=0.8058782310228364, learning_rate=0.06413563546997798, max_depth=3, n_estimators=159, subsample=0.8484712814602339; total time=   1.0s
# [CV] END colsample_bytree=0.8058782310228364, learning_rate=0.06413563546997798, max_depth=3, n_estimators=159, subsample=0.8484712814602339; total time=   1.0s
# [CV] END colsample_bytree=0.8058782310228364, learning_rate=0.06413563546997798, max_depth=3, n_estimators=159, subsample=0.8484712814602339; total time=   1.1s
# [CV] END colsample_bytree=0.8058782310228364, learning_rate=0.06413563546997798, max_depth=3, n_estimators=159, subsample=0.8484712814602339; total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.06448211918775666, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06448211918775666, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06448211918775666, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06448211918775666, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.06448211918775666, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.04963500691638267, max_depth=10, n_estimators=300, subsample=0.8; total time=  20.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.04963500691638267, max_depth=10, n_estimators=300, subsample=0.8; total time=  20.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.04963500691638267, max_depth=10, n_estimators=300, subsample=0.8; total time=  20.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.04963500691638267, max_depth=10, n_estimators=300, subsample=0.8; total time=  21.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.04963500691638267, max_depth=10, n_estimators=300, subsample=0.8; total time=  20.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.02307154840453417, max_depth=7, n_estimators=274, subsample=0.8; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.02307154840453417, max_depth=7, n_estimators=274, subsample=0.8; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.02307154840453417, max_depth=7, n_estimators=274, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.02307154840453417, max_depth=7, n_estimators=274, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.02307154840453417, max_depth=7, n_estimators=274, subsample=0.8; total time=   6.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   1.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.832702718495252, learning_rate=0.19473761170235487, max_depth=3, n_estimators=299, subsample=0.8531059167045835; total time=   2.7s
# [CV] END colsample_bytree=0.832702718495252, learning_rate=0.19473761170235487, max_depth=3, n_estimators=299, subsample=0.8531059167045835; total time=   2.8s
# [CV] END colsample_bytree=0.832702718495252, learning_rate=0.19473761170235487, max_depth=3, n_estimators=299, subsample=0.8531059167045835; total time=   2.7s
# [CV] END colsample_bytree=0.832702718495252, learning_rate=0.19473761170235487, max_depth=3, n_estimators=299, subsample=0.8531059167045835; total time=   2.7s
# [CV] END colsample_bytree=0.832702718495252, learning_rate=0.19473761170235487, max_depth=3, n_estimators=299, subsample=0.8531059167045835; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9481777666911907, learning_rate=0.06816238829586332, max_depth=3, n_estimators=243, subsample=0.8090959178168908; total time=   2.1s
# [CV] END colsample_bytree=0.9481777666911907, learning_rate=0.06816238829586332, max_depth=3, n_estimators=243, subsample=0.8090959178168908; total time=   2.1s
# [CV] END colsample_bytree=0.9481777666911907, learning_rate=0.06816238829586332, max_depth=3, n_estimators=243, subsample=0.8090959178168908; total time=   2.1s
# [CV] END colsample_bytree=0.9481777666911907, learning_rate=0.06816238829586332, max_depth=3, n_estimators=243, subsample=0.8090959178168908; total time=   2.2s
# [CV] END colsample_bytree=0.9481777666911907, learning_rate=0.06816238829586332, max_depth=3, n_estimators=243, subsample=0.8090959178168908; total time=   2.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9442261655484817, learning_rate=0.07407873630783587, max_depth=9, n_estimators=102, subsample=0.8121428692885527; total time=   5.8s
# [CV] END colsample_bytree=0.9442261655484817, learning_rate=0.07407873630783587, max_depth=9, n_estimators=102, subsample=0.8121428692885527; total time=   6.0s
# [CV] END colsample_bytree=0.9442261655484817, learning_rate=0.07407873630783587, max_depth=9, n_estimators=102, subsample=0.8121428692885527; total time=   6.0s
# [CV] END colsample_bytree=0.9442261655484817, learning_rate=0.07407873630783587, max_depth=9, n_estimators=102, subsample=0.8121428692885527; total time=   6.1s
# [CV] END colsample_bytree=0.9442261655484817, learning_rate=0.07407873630783587, max_depth=9, n_estimators=102, subsample=0.8121428692885527; total time=   6.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9834701997259373, learning_rate=0.04031484305107985, max_depth=3, n_estimators=210, subsample=0.840097292842279; total time=   1.7s
# [CV] END colsample_bytree=0.9834701997259373, learning_rate=0.04031484305107985, max_depth=3, n_estimators=210, subsample=0.840097292842279; total time=   1.7s
# [CV] END colsample_bytree=0.9834701997259373, learning_rate=0.04031484305107985, max_depth=3, n_estimators=210, subsample=0.840097292842279; total time=   1.7s
# [CV] END colsample_bytree=0.9834701997259373, learning_rate=0.04031484305107985, max_depth=3, n_estimators=210, subsample=0.840097292842279; total time=   1.7s
# [CV] END colsample_bytree=0.9834701997259373, learning_rate=0.04031484305107985, max_depth=3, n_estimators=210, subsample=0.840097292842279; total time=   1.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9957307669188966, learning_rate=0.04289794618429496, max_depth=7, n_estimators=160, subsample=0.8108967458390266; total time=   4.8s
# [CV] END colsample_bytree=0.9957307669188966, learning_rate=0.04289794618429496, max_depth=7, n_estimators=160, subsample=0.8108967458390266; total time=   4.9s
# [CV] END colsample_bytree=0.9957307669188966, learning_rate=0.04289794618429496, max_depth=7, n_estimators=160, subsample=0.8108967458390266; total time=   4.9s
# [CV] END colsample_bytree=0.9957307669188966, learning_rate=0.04289794618429496, max_depth=7, n_estimators=160, subsample=0.8108967458390266; total time=   5.0s
# [CV] END colsample_bytree=0.9957307669188966, learning_rate=0.04289794618429496, max_depth=7, n_estimators=160, subsample=0.8108967458390266; total time=   5.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.019952821428153363, max_depth=9, n_estimators=300, subsample=0.8; total time=  17.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.019952821428153363, max_depth=9, n_estimators=300, subsample=0.8; total time=  17.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.019952821428153363, max_depth=9, n_estimators=300, subsample=0.8; total time=  17.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.019952821428153363, max_depth=9, n_estimators=300, subsample=0.8; total time=  18.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.019952821428153363, max_depth=9, n_estimators=300, subsample=0.8; total time=  18.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.8529847882598255; total time=  22.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.8529847882598255; total time=  22.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.8529847882598255; total time=  22.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.8529847882598255; total time=  22.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=10, n_estimators=300, subsample=0.8529847882598255; total time=  23.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.10484091768338319, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.10484091768338319, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.10484091768338319, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.10484091768338319, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.10484091768338319, max_depth=5, n_estimators=100, subsample=1.0; total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8983192636864844, learning_rate=0.010286895944108379, max_depth=10, n_estimators=199, subsample=0.8569149205789154; total time=  16.0s
# [CV] END colsample_bytree=0.8983192636864844, learning_rate=0.010286895944108379, max_depth=10, n_estimators=199, subsample=0.8569149205789154; total time=  16.4s
# [CV] END colsample_bytree=0.8983192636864844, learning_rate=0.010286895944108379, max_depth=10, n_estimators=199, subsample=0.8569149205789154; total time=  16.5s
# [CV] END colsample_bytree=0.8983192636864844, learning_rate=0.010286895944108379, max_depth=10, n_estimators=199, subsample=0.8569149205789154; total time=  16.6s
# [CV] END colsample_bytree=0.8983192636864844, learning_rate=0.010286895944108379, max_depth=10, n_estimators=199, subsample=0.8569149205789154; total time=  16.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.07139193821660862, max_depth=5, n_estimators=141, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.07139193821660862, max_depth=5, n_estimators=141, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.07139193821660862, max_depth=5, n_estimators=141, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.07139193821660862, max_depth=5, n_estimators=141, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.07139193821660862, max_depth=5, n_estimators=141, subsample=0.8; total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.825854551820068, learning_rate=0.10769721591360688, max_depth=3, n_estimators=264, subsample=0.8021301895337841; total time=   1.7s
# [CV] END colsample_bytree=0.825854551820068, learning_rate=0.10769721591360688, max_depth=3, n_estimators=264, subsample=0.8021301895337841; total time=   1.7s
# [CV] END colsample_bytree=0.825854551820068, learning_rate=0.10769721591360688, max_depth=3, n_estimators=264, subsample=0.8021301895337841; total time=   1.7s
# [CV] END colsample_bytree=0.825854551820068, learning_rate=0.10769721591360688, max_depth=3, n_estimators=264, subsample=0.8021301895337841; total time=   1.7s
# [CV] END colsample_bytree=0.825854551820068, learning_rate=0.10769721591360688, max_depth=3, n_estimators=264, subsample=0.8021301895337841; total time=   1.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8339229697237331, learning_rate=0.02281970045397454, max_depth=7, n_estimators=200, subsample=0.8177797847498052; total time=   4.9s
# [CV] END colsample_bytree=0.8339229697237331, learning_rate=0.02281970045397454, max_depth=7, n_estimators=200, subsample=0.8177797847498052; total time=   4.9s
# [CV] END colsample_bytree=0.8339229697237331, learning_rate=0.02281970045397454, max_depth=7, n_estimators=200, subsample=0.8177797847498052; total time=   4.9s
# [CV] END colsample_bytree=0.8339229697237331, learning_rate=0.02281970045397454, max_depth=7, n_estimators=200, subsample=0.8177797847498052; total time=   4.9s
# [CV] END colsample_bytree=0.8339229697237331, learning_rate=0.02281970045397454, max_depth=7, n_estimators=200, subsample=0.8177797847498052; total time=   5.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8115910874203607, learning_rate=0.04554812504085595, max_depth=5, n_estimators=199, subsample=0.9136892278733979; total time=   2.6s
# [CV] END colsample_bytree=0.8115910874203607, learning_rate=0.04554812504085595, max_depth=5, n_estimators=199, subsample=0.9136892278733979; total time=   2.6s
# [CV] END colsample_bytree=0.8115910874203607, learning_rate=0.04554812504085595, max_depth=5, n_estimators=199, subsample=0.9136892278733979; total time=   2.7s
# [CV] END colsample_bytree=0.8115910874203607, learning_rate=0.04554812504085595, max_depth=5, n_estimators=199, subsample=0.9136892278733979; total time=   2.7s
# [CV] END colsample_bytree=0.8115910874203607, learning_rate=0.04554812504085595, max_depth=5, n_estimators=199, subsample=0.9136892278733979; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03217801619084713, max_depth=6, n_estimators=205, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03217801619084713, max_depth=6, n_estimators=205, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03217801619084713, max_depth=6, n_estimators=205, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03217801619084713, max_depth=6, n_estimators=205, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03217801619084713, max_depth=6, n_estimators=205, subsample=0.8; total time=   3.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.018632342383135547, max_depth=6, n_estimators=300, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.018632342383135547, max_depth=6, n_estimators=300, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.018632342383135547, max_depth=6, n_estimators=300, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.018632342383135547, max_depth=6, n_estimators=300, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.018632342383135547, max_depth=6, n_estimators=300, subsample=0.8; total time=   4.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8942834313558493, learning_rate=0.014964445210676473, max_depth=10, n_estimators=103, subsample=0.9409501118650885; total time=   9.0s
# [CV] END colsample_bytree=0.8942834313558493, learning_rate=0.014964445210676473, max_depth=10, n_estimators=103, subsample=0.9409501118650885; total time=   9.1s
# [CV] END colsample_bytree=0.8942834313558493, learning_rate=0.014964445210676473, max_depth=10, n_estimators=103, subsample=0.9409501118650885; total time=   9.1s
# [CV] END colsample_bytree=0.8942834313558493, learning_rate=0.014964445210676473, max_depth=10, n_estimators=103, subsample=0.9409501118650885; total time=   9.2s
# [CV] END colsample_bytree=0.8942834313558493, learning_rate=0.014964445210676473, max_depth=10, n_estimators=103, subsample=0.9409501118650885; total time=   9.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8005533104079805, learning_rate=0.04486735933048164, max_depth=6, n_estimators=105, subsample=0.906636746288152; total time=   2.0s
# [CV] END colsample_bytree=0.8005533104079805, learning_rate=0.04486735933048164, max_depth=6, n_estimators=105, subsample=0.906636746288152; total time=   2.0s
# [CV] END colsample_bytree=0.8005533104079805, learning_rate=0.04486735933048164, max_depth=6, n_estimators=105, subsample=0.906636746288152; total time=   2.0s
# [CV] END colsample_bytree=0.8005533104079805, learning_rate=0.04486735933048164, max_depth=6, n_estimators=105, subsample=0.906636746288152; total time=   2.0s
# [CV] END colsample_bytree=0.8005533104079805, learning_rate=0.04486735933048164, max_depth=6, n_estimators=105, subsample=0.906636746288152; total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8241491117248992, learning_rate=0.010200811931347462, max_depth=6, n_estimators=277, subsample=0.8122513185719124; total time=   4.9s
# [CV] END colsample_bytree=0.8241491117248992, learning_rate=0.010200811931347462, max_depth=6, n_estimators=277, subsample=0.8122513185719124; total time=   5.0s
# [CV] END colsample_bytree=0.8241491117248992, learning_rate=0.010200811931347462, max_depth=6, n_estimators=277, subsample=0.8122513185719124; total time=   5.0s
# [CV] END colsample_bytree=0.8241491117248992, learning_rate=0.010200811931347462, max_depth=6, n_estimators=277, subsample=0.8122513185719124; total time=   5.0s
# [CV] END colsample_bytree=0.8241491117248992, learning_rate=0.010200811931347462, max_depth=6, n_estimators=277, subsample=0.8122513185719124; total time=   5.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.05106708816197413, max_depth=7, n_estimators=127, subsample=1.0; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05106708816197413, max_depth=7, n_estimators=127, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05106708816197413, max_depth=7, n_estimators=127, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05106708816197413, max_depth=7, n_estimators=127, subsample=1.0; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05106708816197413, max_depth=7, n_estimators=127, subsample=1.0; total time=   2.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8631476459142464, learning_rate=0.032082829340432696, max_depth=5, n_estimators=147, subsample=0.8010866307347131; total time=   1.7s
# [CV] END colsample_bytree=0.8631476459142464, learning_rate=0.032082829340432696, max_depth=5, n_estimators=147, subsample=0.8010866307347131; total time=   1.7s
# [CV] END colsample_bytree=0.8631476459142464, learning_rate=0.032082829340432696, max_depth=5, n_estimators=147, subsample=0.8010866307347131; total time=   1.8s
# [CV] END colsample_bytree=0.8631476459142464, learning_rate=0.032082829340432696, max_depth=5, n_estimators=147, subsample=0.8010866307347131; total time=   1.8s
# [CV] END colsample_bytree=0.8631476459142464, learning_rate=0.032082829340432696, max_depth=5, n_estimators=147, subsample=0.8010866307347131; total time=   1.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8089093473255736, learning_rate=0.04326068246036572, max_depth=4, n_estimators=266, subsample=0.801431108510266; total time=   2.1s
# [CV] END colsample_bytree=0.8089093473255736, learning_rate=0.04326068246036572, max_depth=4, n_estimators=266, subsample=0.801431108510266; total time=   2.1s
# [CV] END colsample_bytree=0.8089093473255736, learning_rate=0.04326068246036572, max_depth=4, n_estimators=266, subsample=0.801431108510266; total time=   2.2s
# [CV] END colsample_bytree=0.8089093473255736, learning_rate=0.04326068246036572, max_depth=4, n_estimators=266, subsample=0.801431108510266; total time=   2.1s
# [CV] END colsample_bytree=0.8089093473255736, learning_rate=0.04326068246036572, max_depth=4, n_estimators=266, subsample=0.801431108510266; total time=   2.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03845719728199578, max_depth=5, n_estimators=158, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03845719728199578, max_depth=5, n_estimators=158, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03845719728199578, max_depth=5, n_estimators=158, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.03845719728199578, max_depth=5, n_estimators=158, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03845719728199578, max_depth=5, n_estimators=158, subsample=0.8; total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8183102033171796, learning_rate=0.0280192716317363, max_depth=8, n_estimators=129, subsample=0.8769186236386404; total time=   4.5s
# [CV] END colsample_bytree=0.8183102033171796, learning_rate=0.0280192716317363, max_depth=8, n_estimators=129, subsample=0.8769186236386404; total time=   4.5s
# [CV] END colsample_bytree=0.8183102033171796, learning_rate=0.0280192716317363, max_depth=8, n_estimators=129, subsample=0.8769186236386404; total time=   4.6s
# [CV] END colsample_bytree=0.8183102033171796, learning_rate=0.0280192716317363, max_depth=8, n_estimators=129, subsample=0.8769186236386404; total time=   4.6s
# [CV] END colsample_bytree=0.8183102033171796, learning_rate=0.0280192716317363, max_depth=8, n_estimators=129, subsample=0.8769186236386404; total time=   4.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9859207638353422, learning_rate=0.19409900884015885, max_depth=6, n_estimators=102, subsample=0.8115896170846343; total time=   1.9s
# [CV] END colsample_bytree=0.9859207638353422, learning_rate=0.19409900884015885, max_depth=6, n_estimators=102, subsample=0.8115896170846343; total time=   1.9s
# [CV] END colsample_bytree=0.9859207638353422, learning_rate=0.19409900884015885, max_depth=6, n_estimators=102, subsample=0.8115896170846343; total time=   1.8s
# [CV] END colsample_bytree=0.9859207638353422, learning_rate=0.19409900884015885, max_depth=6, n_estimators=102, subsample=0.8115896170846343; total time=   1.9s
# [CV] END colsample_bytree=0.9859207638353422, learning_rate=0.19409900884015885, max_depth=6, n_estimators=102, subsample=0.8115896170846343; total time=   1.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9430735409975209, learning_rate=0.1775611717449062, max_depth=3, n_estimators=238, subsample=0.9962484364364534; total time=   1.8s
# [CV] END colsample_bytree=0.9430735409975209, learning_rate=0.1775611717449062, max_depth=3, n_estimators=238, subsample=0.9962484364364534; total time=   1.7s
# [CV] END colsample_bytree=0.9430735409975209, learning_rate=0.1775611717449062, max_depth=3, n_estimators=238, subsample=0.9962484364364534; total time=   1.8s
# [CV] END colsample_bytree=0.9430735409975209, learning_rate=0.1775611717449062, max_depth=3, n_estimators=238, subsample=0.9962484364364534; total time=   1.8s
# [CV] END colsample_bytree=0.9430735409975209, learning_rate=0.1775611717449062, max_depth=3, n_estimators=238, subsample=0.9962484364364534; total time=   1.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.06870399742436954, max_depth=3, n_estimators=265, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.06870399742436954, max_depth=3, n_estimators=265, subsample=1.0; total time=   1.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.06870399742436954, max_depth=3, n_estimators=265, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.06870399742436954, max_depth=3, n_estimators=265, subsample=1.0; total time=   1.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.06870399742436954, max_depth=3, n_estimators=265, subsample=1.0; total time=   1.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03807432839424711, max_depth=5, n_estimators=300, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03807432839424711, max_depth=5, n_estimators=300, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03807432839424711, max_depth=5, n_estimators=300, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03807432839424711, max_depth=5, n_estimators=300, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03807432839424711, max_depth=5, n_estimators=300, subsample=0.8; total time=   3.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03263121895549338, max_depth=6, n_estimators=152, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03263121895549338, max_depth=6, n_estimators=152, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03263121895549338, max_depth=6, n_estimators=152, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03263121895549338, max_depth=6, n_estimators=152, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03263121895549338, max_depth=6, n_estimators=152, subsample=0.8; total time=   2.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.01927219880687977, max_depth=6, n_estimators=264, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01927219880687977, max_depth=6, n_estimators=264, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01927219880687977, max_depth=6, n_estimators=264, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01927219880687977, max_depth=6, n_estimators=264, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01927219880687977, max_depth=6, n_estimators=264, subsample=0.8; total time=   4.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.050378455347668855, max_depth=4, n_estimators=230, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.050378455347668855, max_depth=4, n_estimators=230, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.050378455347668855, max_depth=4, n_estimators=230, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.050378455347668855, max_depth=4, n_estimators=230, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.050378455347668855, max_depth=4, n_estimators=230, subsample=0.8; total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8315232429682912, learning_rate=0.19866000369099218, max_depth=3, n_estimators=165, subsample=0.8137068398200908; total time=   1.0s
# ...
# [CV] END colsample_bytree=0.8, learning_rate=0.03481293098357939, max_depth=5, n_estimators=195, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03481293098357939, max_depth=5, n_estimators=195, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03481293098357939, max_depth=5, n_estimators=195, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03481293098357939, max_depth=5, n_estimators=195, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03481293098357939, max_depth=5, n_estimators=195, subsample=0.8; total time=   2.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.017646505150848618, max_depth=6, n_estimators=276, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.017646505150848618, max_depth=6, n_estimators=276, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.017646505150848618, max_depth=6, n_estimators=276, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.017646505150848618, max_depth=6, n_estimators=276, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.017646505150848618, max_depth=6, n_estimators=276, subsample=0.8; total time=   4.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8070928253962019, learning_rate=0.011800159497093473, max_depth=8, n_estimators=257, subsample=0.8202212476238275; total time=   9.5s
# [CV] END colsample_bytree=0.8070928253962019, learning_rate=0.011800159497093473, max_depth=8, n_estimators=257, subsample=0.8202212476238275; total time=   9.7s
# [CV] END colsample_bytree=0.8070928253962019, learning_rate=0.011800159497093473, max_depth=8, n_estimators=257, subsample=0.8202212476238275; total time=   9.7s
# [CV] END colsample_bytree=0.8070928253962019, learning_rate=0.011800159497093473, max_depth=8, n_estimators=257, subsample=0.8202212476238275; total time=   9.8s
# [CV] END colsample_bytree=0.8070928253962019, learning_rate=0.011800159497093473, max_depth=8, n_estimators=257, subsample=0.8202212476238275; total time=   9.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9745897548305804, learning_rate=0.057675331994968396, max_depth=4, n_estimators=300, subsample=0.992593648239689; total time=   2.7s
# [CV] END colsample_bytree=0.9745897548305804, learning_rate=0.057675331994968396, max_depth=4, n_estimators=300, subsample=0.992593648239689; total time=   2.7s
# [CV] END colsample_bytree=0.9745897548305804, learning_rate=0.057675331994968396, max_depth=4, n_estimators=300, subsample=0.992593648239689; total time=   2.8s
# [CV] END colsample_bytree=0.9745897548305804, learning_rate=0.057675331994968396, max_depth=4, n_estimators=300, subsample=0.992593648239689; total time=   2.8s
# [CV] END colsample_bytree=0.9745897548305804, learning_rate=0.057675331994968396, max_depth=4, n_estimators=300, subsample=0.992593648239689; total time=   2.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9965706222990585, learning_rate=0.01499023107627882, max_depth=5, n_estimators=268, subsample=0.8026802631290851; total time=   3.3s
# [CV] END colsample_bytree=0.9965706222990585, learning_rate=0.01499023107627882, max_depth=5, n_estimators=268, subsample=0.8026802631290851; total time=   3.3s
# [CV] END colsample_bytree=0.9965706222990585, learning_rate=0.01499023107627882, max_depth=5, n_estimators=268, subsample=0.8026802631290851; total time=   3.3s
# [CV] END colsample_bytree=0.9965706222990585, learning_rate=0.01499023107627882, max_depth=5, n_estimators=268, subsample=0.8026802631290851; total time=   3.4s
# [CV] END colsample_bytree=0.9965706222990585, learning_rate=0.01499023107627882, max_depth=5, n_estimators=268, subsample=0.8026802631290851; total time=   3.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8611513520467937, learning_rate=0.05107655849821228, max_depth=4, n_estimators=102, subsample=0.8218582897393855; total time=   1.2s
# [CV] END colsample_bytree=0.8611513520467937, learning_rate=0.05107655849821228, max_depth=4, n_estimators=102, subsample=0.8218582897393855; total time=   1.2s
# [CV] END colsample_bytree=0.8611513520467937, learning_rate=0.05107655849821228, max_depth=4, n_estimators=102, subsample=0.8218582897393855; total time=   1.2s
# [CV] END colsample_bytree=0.8611513520467937, learning_rate=0.05107655849821228, max_depth=4, n_estimators=102, subsample=0.8218582897393855; total time=   1.2s
# [CV] END colsample_bytree=0.8611513520467937, learning_rate=0.05107655849821228, max_depth=4, n_estimators=102, subsample=0.8218582897393855; total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8174465129192323, learning_rate=0.03063374729752408, max_depth=9, n_estimators=191, subsample=0.9744391852461722; total time=   9.6s
# [CV] END colsample_bytree=0.8174465129192323, learning_rate=0.03063374729752408, max_depth=9, n_estimators=191, subsample=0.9744391852461722; total time=   9.7s
# [CV] END colsample_bytree=0.8174465129192323, learning_rate=0.03063374729752408, max_depth=9, n_estimators=191, subsample=0.9744391852461722; total time=   9.7s
# [CV] END colsample_bytree=0.8174465129192323, learning_rate=0.03063374729752408, max_depth=9, n_estimators=191, subsample=0.9744391852461722; total time=  10.0s
# [CV] END colsample_bytree=0.8174465129192323, learning_rate=0.03063374729752408, max_depth=9, n_estimators=191, subsample=0.9744391852461722; total time=  10.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.035385744218849075, max_depth=5, n_estimators=241, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.035385744218849075, max_depth=5, n_estimators=241, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.035385744218849075, max_depth=5, n_estimators=241, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.035385744218849075, max_depth=5, n_estimators=241, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.035385744218849075, max_depth=5, n_estimators=241, subsample=0.8; total time=   2.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03549342390692339, max_depth=5, n_estimators=242, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03549342390692339, max_depth=5, n_estimators=242, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03549342390692339, max_depth=5, n_estimators=242, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03549342390692339, max_depth=5, n_estimators=242, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03549342390692339, max_depth=5, n_estimators=242, subsample=0.8; total time=   2.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8896886556225816, learning_rate=0.11170437050902357, max_depth=8, n_estimators=299, subsample=0.8269657718870697; total time=  10.6s
# [CV] END colsample_bytree=0.8896886556225816, learning_rate=0.11170437050902357, max_depth=8, n_estimators=299, subsample=0.8269657718870697; total time=  10.7s
# [CV] END colsample_bytree=0.8896886556225816, learning_rate=0.11170437050902357, max_depth=8, n_estimators=299, subsample=0.8269657718870697; total time=  10.7s
# [CV] END colsample_bytree=0.8896886556225816, learning_rate=0.11170437050902357, max_depth=8, n_estimators=299, subsample=0.8269657718870697; total time=  10.7s
# [CV] END colsample_bytree=0.8896886556225816, learning_rate=0.11170437050902357, max_depth=8, n_estimators=299, subsample=0.8269657718870697; total time=  10.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.03743976701797366, max_depth=4, n_estimators=245, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03743976701797366, max_depth=4, n_estimators=245, subsample=0.8; total time=   2.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03743976701797366, max_depth=4, n_estimators=245, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03743976701797366, max_depth=4, n_estimators=245, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03743976701797366, max_depth=4, n_estimators=245, subsample=0.8; total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9919447648789215, learning_rate=0.02859649220285813, max_depth=7, n_estimators=104, subsample=0.9922685092499541; total time=   2.7s
# [CV] END colsample_bytree=0.9919447648789215, learning_rate=0.02859649220285813, max_depth=7, n_estimators=104, subsample=0.9922685092499541; total time=   2.7s
# [CV] END colsample_bytree=0.9919447648789215, learning_rate=0.02859649220285813, max_depth=7, n_estimators=104, subsample=0.9922685092499541; total time=   2.7s
# [CV] END colsample_bytree=0.9919447648789215, learning_rate=0.02859649220285813, max_depth=7, n_estimators=104, subsample=0.9922685092499541; total time=   2.7s
# [CV] END colsample_bytree=0.9919447648789215, learning_rate=0.02859649220285813, max_depth=7, n_estimators=104, subsample=0.9922685092499541; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03583650122074646, max_depth=5, n_estimators=254, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03583650122074646, max_depth=5, n_estimators=254, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03583650122074646, max_depth=5, n_estimators=254, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03583650122074646, max_depth=5, n_estimators=254, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03583650122074646, max_depth=5, n_estimators=254, subsample=0.8; total time=   3.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.0362850959037308, max_depth=5, n_estimators=228, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.0362850959037308, max_depth=5, n_estimators=228, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.0362850959037308, max_depth=5, n_estimators=228, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.0362850959037308, max_depth=5, n_estimators=228, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.0362850959037308, max_depth=5, n_estimators=228, subsample=0.8; total time=   2.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   0.8s
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   0.8s
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   0.8s
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   0.8s
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   0.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9989426740618481, learning_rate=0.07052663455128023, max_depth=6, n_estimators=101, subsample=0.9016789617650611; total time=   1.7s
# [CV] END colsample_bytree=0.9989426740618481, learning_rate=0.07052663455128023, max_depth=6, n_estimators=101, subsample=0.9016789617650611; total time=   1.8s
# [CV] END colsample_bytree=0.9989426740618481, learning_rate=0.07052663455128023, max_depth=6, n_estimators=101, subsample=0.9016789617650611; total time=   1.7s
# [CV] END colsample_bytree=0.9989426740618481, learning_rate=0.07052663455128023, max_depth=6, n_estimators=101, subsample=0.9016789617650611; total time=   1.7s
# [CV] END colsample_bytree=0.9989426740618481, learning_rate=0.07052663455128023, max_depth=6, n_estimators=101, subsample=0.9016789617650611; total time=   1.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.802240009235396, learning_rate=0.06512070762447239, max_depth=6, n_estimators=204, subsample=0.8203877856204729; total time=   3.1s
# [CV] END colsample_bytree=0.802240009235396, learning_rate=0.06512070762447239, max_depth=6, n_estimators=204, subsample=0.8203877856204729; total time=   3.2s
# [CV] END colsample_bytree=0.802240009235396, learning_rate=0.06512070762447239, max_depth=6, n_estimators=204, subsample=0.8203877856204729; total time=   3.1s
# [CV] END colsample_bytree=0.802240009235396, learning_rate=0.06512070762447239, max_depth=6, n_estimators=204, subsample=0.8203877856204729; total time=   3.2s
# [CV] END colsample_bytree=0.802240009235396, learning_rate=0.06512070762447239, max_depth=6, n_estimators=204, subsample=0.8203877856204729; total time=   3.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03271089159663848, max_depth=5, n_estimators=252, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03271089159663848, max_depth=5, n_estimators=252, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03271089159663848, max_depth=5, n_estimators=252, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03271089159663848, max_depth=5, n_estimators=252, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03271089159663848, max_depth=5, n_estimators=252, subsample=0.8; total time=   3.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03202658624561261, max_depth=5, n_estimators=255, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.03202658624561261, max_depth=5, n_estimators=255, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03202658624561261, max_depth=5, n_estimators=255, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03202658624561261, max_depth=5, n_estimators=255, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03202658624561261, max_depth=5, n_estimators=255, subsample=0.8; total time=   3.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.031931612097090355, max_depth=5, n_estimators=257, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.031931612097090355, max_depth=5, n_estimators=257, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.031931612097090355, max_depth=5, n_estimators=257, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.031931612097090355, max_depth=5, n_estimators=257, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.031931612097090355, max_depth=5, n_estimators=257, subsample=0.8; total time=   2.8s
#
# Best hyperparameters: OrderedDict({'colsample_bytree': 0.8, 'learning_rate': 0.03271089159663848, 'max_depth': 5, 'n_estimators': 252, 'subsample': 0.8})
# Best cross-validation R² score: 0.7262
# Standard deviation: 0.0341
# Bayesian search completed in 611.93 seconds

# %%
# =============================================================================
# XGBOOST MODEL - For ML Model Comparisons
# =============================================================================

# Use the best model from grid search
best_xgb_model = grid_search.best_estimator_

# Predictions
y_train_pred = best_xgb_model.predict(X_train)
y_test_pred = best_xgb_model.predict(X_test)

# Simple metrics function for any model
def print_model_performance(y_true, y_pred, model_name, dataset):
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    print(f"{model_name} ({dataset}): R²={r2:.4f} | RMSE={rmse:.4f} | MAE={mae:.4f}")

# Print results
print("XGBOOST PERFORMANCE (SET A + SET B FEATURES):")
print_model_performance(y_train, y_train_pred, "XGBoost", "Train")
print_model_performance(y_test, y_test_pred, "XGBoost", "Test")
# Out:
# XGBOOST PERFORMANCE (SET A + SET B FEATURES):
# XGBoost (Train): R²=0.8221 | RMSE=0.4470 | MAE=0.1550
# XGBoost (Test): R²=0.6832 | RMSE=0.5490 | MAE=0.1873

# %%
# =============================================================================
# FEATURE IMPORTANCE ANALYSIS
# =============================================================================

import pandas as pd

# Get feature importances
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': best_xgb_model.feature_importances_
}).sort_values('importance', ascending=False)

print("FEATURE IMPORTANCE RANKING (SET A + SET B FEATURES):")
print("="*50)
for i, (_, row) in enumerate(feature_importance.iterrows(), 1):
    print(f"{i:2d}. {row['feature']:<25} {row['importance']:.4f}")

# Print model details
print(f"\nMODEL DETAILS:")
print(f"Max Depth: {best_xgb_model.max_depth}")
print(f"Learning Rate: {best_xgb_model.learning_rate}")
print(f"N Estimators: {best_xgb_model.n_estimators}")
print(f"Subsample: {best_xgb_model.subsample}")
print(f"Colsample Bytree: {best_xgb_model.colsample_bytree}")
print(f"Number of Features: {best_xgb_model.n_features_in_}")
# Out:
# FEATURE IMPORTANCE RANKING (SET A + SET B FEATURES):
# ==================================================
#  1. NI_Scaled_t               0.3432
#  2. XSGA_Scaled_t             0.1433
#  3. ln_at_t                   0.0880
#  4. OCF_Scaled_Lag_t          0.0809
#  5. OCFtoSales_t              0.0338
#  6. ASC606_dummy              0.0299
#  7. DebtToAssets_t            0.0288
#  8. XRD_Scaled_t              0.0269
#  9. TCJA_dummy                0.0261
# 10. Accruals_Scaled_t         0.0185
# 11. MkBk_t                    0.0182
# 12. InvTurnover_t             0.0166
# 13. Delta_AP_Scaled_t         0.0162
# 14. NI_Scaled_Lag_t           0.0157
# 15. FirmAge_t                 0.0125
# 16. CurrentRatio_t            0.0125
# 17. RecTurnover_t             0.0125
# 18. CapitalIntensity_t        0.0121
# 19. Delta_Rec_Scaled_t        0.0120
# 20. Delta_Sales_Scaled_t      0.0118
# 21. DP_Scaled_t               0.0113
# 22. GPM_t                     0.0111
# 23. CAPX_Scaled_t             0.0100
# 24. Delta_Inv_Scaled_t        0.0079
#
# MODEL DETAILS:
# Max Depth: 5
# Learning Rate: 0.03271089159663848
# N Estimators: 252
# Subsample: 0.8
# Colsample Bytree: 0.8
# Number of Features: 24
