# %%
# Enable auto-reloading of external modules - useful during development
# %load_ext autoreload
# %autoreload 2

# Configure Python path to find our custom modules
import sys
from pathlib import Path

# Add project root to the Python path for proper imports
project_root = Path.cwd().parent
if project_root not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
# Import necessary libraries
import src.processing as processing
import src.config as lists

# %%
# Load and process data
df = processing.load_data("/Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/data/raw/nvzfxcoxdvh1at7i.csv")
df_prepared = processing.prepare_data(df)
df_added_features = processing.create_all_model_features_orchestrated(df_prepared)
df_missing = processing.drop_missing_final_vars_streamlined(df_added_features, lists.final_set_A_predictor_names_and_dependent)
df_final = processing.annual_winsorize_variables(df_missing, lists.columns_to_winsorize)
# Out:
# /Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/src/processing.py:42: DtypeWarning: Columns (10,11,12,16,17,22,26,30,33,34,35,945,946,948,949,950,955,969,970,975,980) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# Data loaded successfully from /Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/data/raw/nvzfxcoxdvh1at7i.csv
# Original number of observations: 317304
# Number of columns after selection: 30
# Observations after year filter (2000-2023): 302751
# Observations after excluding financial and utility firms: 170598
# Starting feature construction. Initial df shape: (170598, 30)
#   Creating lags for: ['at', 'ni', 'rect', 'invt', 'ap', 'sale']
#
# Performing pre-calculation validity checks & preparations...
#   Missing 'xrd' values filled with 0.
#   'ipo_year' created from 'ipodate'.
#
# Constructing dependent variable...
#   OCF_Scaled_t_plus_1 created.
#
# Constructing Set A (OLS) predictors...
#   Set A predictors constructed.
#
# Constructing control dummy variables...
#   Dummy variables constructed.
#
# Constructing Set B (additional ML) predictors...
#   Creating lags for: ['at', 'ni', 'rect', 'invt', 'ap', 'sale']
#
# Performing pre-calculation validity checks & preparations...
#   Missing 'xrd' values filled with 0.
#   'ipo_year' created from 'ipodate'.
#
# Constructing dependent variable...
#   OCF_Scaled_t_plus_1 created.
#
# Constructing Set A (OLS) predictors...
#   Set A predictors constructed.
#
# Constructing control dummy variables...
#   Dummy variables constructed.
#
# Constructing Set B (additional ML) predictors...
#   Set B predictors constructed.
#
# Selecting final model variables and dropping intermediate columns...
#   Shape of DataFrame after final column selection: (170598, 30)
#   Final columns kept: 30 columns
#
# Feature construction complete. Final DataFrame shape: (170598, 30)
#
# Starting final dropna. Initial rows: 170598, DataFrame shape: (170598, 30)
#   Rows dropped due to NaNs in critical model variables: 47149
#   Shape of analytical sample AFTER final dropna: (123449, 30)
#   Verification: No NaNs in checked columns of analytical sample.
#
# Starting annual winsorization for 22 columns...
#   Winsorizing column: Accruals_Scaled_t
#   Winsorizing column: CAPX_Scaled_t
#   Winsorizing column: CapitalIntensity_t
#   Winsorizing column: CurrentRatio_t
#   Winsorizing column: DP_Scaled_t
#   Winsorizing column: DebtToAssets_t
#   Winsorizing column: Delta_AP_Scaled_t
#   Winsorizing column: Delta_Inv_Scaled_t
#   Winsorizing column: Delta_Rec_Scaled_t
#   Winsorizing column: Delta_Sales_Scaled_t
#   Set B predictors constructed.
#
# Selecting final model variables and dropping intermediate columns...
#   Shape of DataFrame after final column selection: (170598, 30)
#   Final columns kept: 30 columns
#
# Feature construction complete. Final DataFrame shape: (170598, 30)
#
# Starting final dropna. Initial rows: 170598, DataFrame shape: (170598, 30)
#   Rows dropped due to NaNs in critical model variables: 47149
#   Shape of analytical sample AFTER final dropna: (123449, 30)
#   Verification: No NaNs in checked columns of analytical sample.
#
# Starting annual winsorization for 22 columns...
#   Winsorizing column: Accruals_Scaled_t
#   Winsorizing column: CAPX_Scaled_t
#   Winsorizing column: CapitalIntensity_t
#   Winsorizing column: CurrentRatio_t
#   Winsorizing column: DP_Scaled_t
#   Winsorizing column: DebtToAssets_t
#   Winsorizing column: Delta_AP_Scaled_t
#   Winsorizing column: Delta_Inv_Scaled_t
#   Winsorizing column: Delta_Rec_Scaled_t
#   Winsorizing column: Delta_Sales_Scaled_t
#   Winsorizing column: GPM_t
#   Winsorizing column: InvTurnover_t
#   Winsorizing column: MkBk_t
#   Winsorizing column: NI_Scaled_Lag_t
#   Winsorizing column: NI_Scaled_t
#   Winsorizing column: OCF_Scaled_Lag_t
#   Winsorizing column: OCF_Scaled_t_plus_1
#   Winsorizing column: OCFtoSales_t
#   Winsorizing column: RecTurnover_t
#   Winsorizing column: XRD_Scaled_t
#   Winsorizing column: XSGA_Scaled_t
#   Winsorizing column: ln_at_t
#   Winsorizing column: GPM_t
#   Winsorizing column: InvTurnover_t
#   Winsorizing column: MkBk_t
#   Winsorizing column: NI_Scaled_Lag_t
#   Winsorizing column: NI_Scaled_t
#   Winsorizing column: OCF_Scaled_Lag_t
#   Winsorizing column: OCF_Scaled_t_plus_1
#   Winsorizing column: OCFtoSales_t
#   Winsorizing column: RecTurnover_t
#   Winsorizing column: XRD_Scaled_t
#   Winsorizing column: XSGA_Scaled_t
#   Winsorizing column: ln_at_t
# Annual winsorization complete.
# Annual winsorization complete.

# %%
# Split data chronologically - train on pre-2018, test on 2018+
train_df, test_df = processing.split_data_chronologically(df_final, 'fyear', split_year=2018)

print(f"Training data shape: {train_df.shape}")
print(f"Test data shape: {test_df.shape}")
print(f"Training period: {train_df['fyear'].min()} - {train_df['fyear'].max()}")
print(f"Test period: {test_df['fyear'].min()} - {test_df['fyear'].max()}")
# Out:
# Training set: 102567 obs (Predictor years <= 2018)
# Test set: 20882 obs (Predictor years > 2018)
# Training data shape: (102567, 30)
# Test data shape: (20882, 30)
# Training period: 2001.0 - 2018.0
# Test period: 2019.0 - 2022.0

# %%
# Set B (Additional ML) predictor feature names
SET_B_FEATURES = [
    'XSGA_Scaled_t', 'XRD_Scaled_t', 'CAPX_Scaled_t', 'CurrentRatio_t',
    'DebtToAssets_t', 'OCFtoSales_t', 'InvTurnover_t', 'RecTurnover_t',
    'GPM_t', 'Delta_Sales_Scaled_t', 'NI_Scaled_Lag_t',
    'CapitalIntensity_t', 'MkBk_t', 'FirmAge_t'
]

# Prepare features and dependent variable for XGBoost regression
# Using SET_A + SET_B + dummy controls to show the full power of ML
X_train = train_df[lists.SET_A_FEATURES + SET_B_FEATURES + lists.CONTROL_DUMMY_FEATURES]
y_train = train_df[lists.DEPENDENT_VARIABLE]

X_test = test_df[lists.SET_A_FEATURES + SET_B_FEATURES + lists.CONTROL_DUMMY_FEATURES]
y_test = test_df[lists.DEPENDENT_VARIABLE]

# Drop dummy variables that caused multicollinearity in OLS
X_train = X_train.drop(columns=['ASC842_dummy', 'COVID_dummy'])
X_test = X_test.drop(columns=['ASC842_dummy', 'COVID_dummy'])

print("Features included in the model:")
for i, feature in enumerate(X_train.columns, 1):
    print(f"{i:2d}. {feature}")

print(f"\nDependent variable: {lists.DEPENDENT_VARIABLE}")
print(f"Training observations: {len(X_train)}")
print(f"Test observations: {len(X_test)}")
# Out:
# Features included in the model:
#  1. XSGA_Scaled_t
#  2. XRD_Scaled_t
#  3. CAPX_Scaled_t
#  4. CurrentRatio_t
#  5. DebtToAssets_t
#  6. OCFtoSales_t
#  7. InvTurnover_t
#  8. RecTurnover_t
#  9. GPM_t
# 10. Delta_Sales_Scaled_t
# 11. NI_Scaled_Lag_t
# 12. CapitalIntensity_t
# 13. MkBk_t
# 14. FirmAge_t
# 15. ASC606_dummy
# 16. TCJA_dummy
#
# Dependent variable: OCF_Scaled_t_plus_1
# Training observations: 102567
# Test observations: 20882

# %%
# =============================================================================
# BAYESIAN OPTIMIZATION FOR HYPERPARAMETER TUNING
# =============================================================================

import xgboost as xgb
from skopt import BayesSearchCV
from skopt.space import Real, Integer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np
import time

# Define hyperparameter search space for Bayesian optimization
search_space = {
    'max_depth': Integer(3, 10),
    'learning_rate': Real(0.01, 0.2, prior='log-uniform'),
    'n_estimators': Integer(100, 300),
    'subsample': Real(0.8, 1.0),
    'colsample_bytree': Real(0.8, 1.0)
}

# Create XGBoost regressor
xgb_regressor = xgb.XGBRegressor(random_state=42, objective='reg:squarederror')

# Perform Bayesian Search with 5-fold cross-validation
print("Performing 5-fold cross-validation for XGBoost Bayesian hyperparameter tuning...")
print(f"Search space dimensions: {len(search_space)}")
print(f"Number of iterations: 100 (intelligent sampling)")

start_time = time.time()

bayes_search = BayesSearchCV(
    estimator=xgb_regressor,
    search_spaces=search_space,
    n_iter=100,  # Number of parameter settings to try
    cv=5,
    scoring='r2',
    n_jobs=-1,
    random_state=42,
    verbose=2  # Increased verbosity for more detailed progress information
)

# Fit the bayesian search
bayes_search.fit(X_train, y_train)

# Print best parameters and score
print(f"\nBest hyperparameters: {bayes_search.best_params_}")
print(f"Best cross-validation R² score: {bayes_search.best_score_:.4f}")
print(f"Standard deviation: {bayes_search.cv_results_['std_test_score'][bayes_search.best_index_]:.4f}")

elapsed_time = time.time() - start_time
print(f"Bayesian search completed in {elapsed_time:.2f} seconds")

# For compatibility with rest of the code, assign to grid_search variable
grid_search = bayes_search
# Out:
# Performing 5-fold cross-validation for XGBoost Bayesian hyperparameter tuning...
# Search space dimensions: 5
# Number of iterations: 100 (intelligent sampling)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.2s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.3s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.4s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.4s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.2s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.3s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.4s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.4s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   4.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.3s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.4s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.4s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.3s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.4s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.4s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.2s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.2s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.1s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   0.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   0.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.3s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.3s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.4s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.4s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.3s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.3s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.4s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.4s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   3.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   2.9s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   2.9s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   2.9s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   3.0s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   2.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   2.9s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   2.9s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   2.9s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   3.0s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   2.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   0.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   1.9s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   1.9s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   1.9s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   2.0s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   1.9s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   1.9s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   1.9s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   2.0s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.5s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.6s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.7s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.7s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.7s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.5s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.6s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.7s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.7s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=   4.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=   2.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=1.0; total time=   9.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.028545087556598684, max_depth=10, n_estimators=300, subsample=0.8; total time=   9.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=3, n_estimators=237, subsample=1.0; total time=   0.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.01, max_depth=10, n_estimators=227, subsample=1.0; total time=  10.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=193, subsample=1.0; total time=   0.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03792195678451642, max_depth=3, n_estimators=300, subsample=1.0; total time=   1.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.019446898197371155, max_depth=7, n_estimators=293, subsample=1.0; total time=   3.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   0.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   1.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.06536717579575055, max_depth=3, n_estimators=243, subsample=1.0; total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=  10.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=  10.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=  10.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=  10.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=  10.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.017643035780643992, max_depth=10, n_estimators=263, subsample=1.0; total time=  10.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=1.0; total time=   4.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.8319208268352666, learning_rate=0.10238929457706122, max_depth=3, n_estimators=100, subsample=1.0; total time=   0.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8078139629881069, learning_rate=0.02672968185497853, max_depth=3, n_estimators=261, subsample=0.8; total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.10456291032428833, max_depth=3, n_estimators=172, subsample=1.0; total time=   0.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.0s
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.0s
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.1s
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.1s
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.0s
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.0s
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.1s
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.1s
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.2s
# [CV] END colsample_bytree=0.8071471565847401, learning_rate=0.05377208079854025, max_depth=10, n_estimators=104, subsample=0.9843839147270883; total time=   4.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.012486693566725588, max_depth=8, n_estimators=300, subsample=0.8; total time=   9.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.07647697921830734, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.09867548829023637, max_depth=3, n_estimators=262, subsample=1.0; total time=   2.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03798207004347228, max_depth=6, n_estimators=164, subsample=1.0; total time=   6.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8720399181164943, learning_rate=0.025961097931941055, max_depth=10, n_estimators=156, subsample=0.8166303381379674; total time=  27.3s
# [CV] END colsample_bytree=0.8720399181164943, learning_rate=0.025961097931941055, max_depth=10, n_estimators=156, subsample=0.8166303381379674; total time=  27.3s
# [CV] END colsample_bytree=0.8720399181164943, learning_rate=0.025961097931941055, max_depth=10, n_estimators=156, subsample=0.8166303381379674; total time=  27.4s
# [CV] END colsample_bytree=0.8720399181164943, learning_rate=0.025961097931941055, max_depth=10, n_estimators=156, subsample=0.8166303381379674; total time=  27.4s
# [CV] END colsample_bytree=0.8720399181164943, learning_rate=0.025961097931941055, max_depth=10, n_estimators=156, subsample=0.8166303381379674; total time=  27.3s
# [CV] END colsample_bytree=0.8720399181164943, learning_rate=0.025961097931941055, max_depth=10, n_estimators=156, subsample=0.8166303381379674; total time=  27.3s
# ...
# [CV] END colsample_bytree=0.8, learning_rate=0.015544148279873259, max_depth=7, n_estimators=232, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.015544148279873259, max_depth=7, n_estimators=232, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.015544148279873259, max_depth=7, n_estimators=232, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.015544148279873259, max_depth=7, n_estimators=232, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.015544148279873259, max_depth=7, n_estimators=232, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.015544148279873259, max_depth=7, n_estimators=232, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.015544148279873259, max_depth=7, n_estimators=232, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.015544148279873259, max_depth=7, n_estimators=232, subsample=0.8; total time=   7.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.4s
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.4s
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.4s
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.4s
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.5s
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.4s
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.4s
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.4s
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.4s
# [CV] END colsample_bytree=0.9979113514650988, learning_rate=0.07735603477089216, max_depth=4, n_estimators=153, subsample=0.9534775660879922; total time=   1.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.017311590702841394, max_depth=6, n_estimators=300, subsample=0.8; total time=   7.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.020858361756124932, max_depth=6, n_estimators=219, subsample=0.8; total time=   4.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.1s
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.1s
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.5s
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.5s
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.6s
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.6s
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.5s
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.5s
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.6s
# [CV] END colsample_bytree=0.8134990318918571, learning_rate=0.03404453158049941, max_depth=10, n_estimators=120, subsample=0.9953444709061493; total time=  11.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# [CV] END colsample_bytree=0.8728628120523594, learning_rate=0.021821371800056923, max_depth=6, n_estimators=102, subsample=0.8153923322725034; total time=   1.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.2s
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.2s
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.2s
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.2s
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.3s
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.2s
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.2s
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.2s
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.2s
# [CV] END colsample_bytree=0.877008890933792, learning_rate=0.05579459717443222, max_depth=6, n_estimators=106, subsample=0.9962073791498355; total time=   2.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03168959811638878, max_depth=7, n_estimators=100, subsample=0.8; total time=   3.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.02310874480481165, max_depth=6, n_estimators=183, subsample=0.8; total time=   3.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  19.7s
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  19.8s
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  19.8s
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  19.9s
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  19.7s
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  19.8s
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  19.8s
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  19.9s
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  20.2s
# [CV] END colsample_bytree=0.8091797297705948, learning_rate=0.116362183411583, max_depth=10, n_estimators=294, subsample=0.9368883515956206; total time=  20.2s
#
# Best hyperparameters: OrderedDict({'colsample_bytree': 0.8, 'learning_rate': 0.01819101523218433, 'max_depth': 7, 'n_estimators': 222, 'subsample': 0.8})
# Best cross-validation R² score: 0.6829
# Standard deviation: 0.0356
# Bayesian search completed in 711.19 seconds
#
# Best hyperparameters: OrderedDict({'colsample_bytree': 0.8, 'learning_rate': 0.01819101523218433, 'max_depth': 7, 'n_estimators': 222, 'subsample': 0.8})
# Best cross-validation R² score: 0.6829
# Standard deviation: 0.0356
# Bayesian search completed in 711.19 seconds

# %%
# =============================================================================
# XGBOOST MODEL - For ML Model Comparisons
# =============================================================================

# Use the best model from grid search
best_xgb_model = grid_search.best_estimator_

# Predictions
y_train_pred = best_xgb_model.predict(X_train)
y_test_pred = best_xgb_model.predict(X_test)

# Simple metrics function for any model
def print_model_performance(y_true, y_pred, model_name, dataset):
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    print(f"{model_name} ({dataset}): R²={r2:.4f} | RMSE={rmse:.4f} | MAE={mae:.4f}")

# Print results
print("XGBOOST PERFORMANCE (SET A + SET B FEATURES):")
print_model_performance(y_train, y_train_pred, "XGBoost", "Train")
print_model_performance(y_test, y_test_pred, "XGBoost", "Test")
# Out:
# XGBOOST PERFORMANCE (SET B FEATURES):
# XGBoost (Train): R²=0.8015 | RMSE=0.4721 | MAE=0.1607
# XGBoost (Test): R²=0.6668 | RMSE=0.5630 | MAE=0.1936

# %%
# =============================================================================
# FEATURE IMPORTANCE ANALYSIS
# =============================================================================

import pandas as pd

# Get feature importances
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': best_xgb_model.feature_importances_
}).sort_values('importance', ascending=False)

print("FEATURE IMPORTANCE RANKING (SET A + SET B FEATURES):")
print("="*50)
for i, (_, row) in enumerate(feature_importance.iterrows(), 1):
    print(f"{i:2d}. {row['feature']:<25} {row['importance']:.4f}")

# Print model details
print(f"\nMODEL DETAILS:")
print(f"Max Depth: {best_xgb_model.max_depth}")
print(f"Learning Rate: {best_xgb_model.learning_rate}")
print(f"N Estimators: {best_xgb_model.n_estimators}")
print(f"Subsample: {best_xgb_model.subsample}")
print(f"Colsample Bytree: {best_xgb_model.colsample_bytree}")
print(f"Number of Features: {best_xgb_model.n_features_in_}")
# Out:
# FEATURE IMPORTANCE RANKING (SET B FEATURES):
# ==================================================
#  1. XSGA_Scaled_t             0.3365
#  2. DebtToAssets_t            0.1677
#  3. NI_Scaled_Lag_t           0.1102
#  4. OCFtoSales_t              0.0783
#  5. ASC606_dummy              0.0417
#  6. XRD_Scaled_t              0.0405
#  7. TCJA_dummy                0.0366
#  8. MkBk_t                    0.0317
#  9. CurrentRatio_t            0.0303
# 10. GPM_t                     0.0229
# 11. FirmAge_t                 0.0203
# 12. CapitalIntensity_t        0.0190
# 13. RecTurnover_t             0.0177
# 14. Delta_Sales_Scaled_t      0.0162
# 15. InvTurnover_t             0.0155
# 16. CAPX_Scaled_t             0.0150
#
# MODEL DETAILS:
# Max Depth: 7
# Learning Rate: 0.01819101523218433
# N Estimators: 222
# Subsample: 0.8
# Colsample Bytree: 0.8
# Number of Features: 16
