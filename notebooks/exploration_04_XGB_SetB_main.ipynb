# %%
# Enable auto-reloading of external modules - useful during development
# %load_ext autoreload
# %autoreload 2

# Configure Python path to find our custom modules
import sys
from pathlib import Path

# Add project root to the Python path for proper imports
project_root = Path.cwd().parent
if project_root not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
# Import necessary libraries
import src.processing as processing
import src.config as lists

# %%
# Load and process data
df = processing.load_data("/Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/data/raw/nvzfxcoxdvh1at7i.csv")
df_prepared = processing.prepare_data(df)
df_added_features = processing.create_all_model_features_orchestrated(df_prepared)
df_missing = processing.drop_missing_final_vars_streamlined(df_added_features, lists.final_set_A_predictor_names_and_dependent)
df_final = processing.annual_winsorize_variables(df_missing, lists.columns_to_winsorize)
# Out:
# /Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/src/processing.py:41: DtypeWarning: Columns (10,11,12,16,17,22,26,30,33,34,35,945,946,948,949,950,955,969,970,975,980) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# Data loaded successfully from /Users/luis.m/Library/Mobile Documents/com~apple~CloudDocs/Documents ☁️/VSC Projects/Master_Thesis/data/raw/nvzfxcoxdvh1at7i.csv
# Original number of observations: 317304
# Number of columns after selection: 30
# Observations after year filter (2000-2023): 302751
# Observations after excluding financial and utility firms: 170598
# Starting feature construction. Initial df shape: (170598, 30)
#   Creating lags for: ['at', 'ni', 'rect', 'invt', 'ap', 'sale']
#
# Performing pre-calculation validity checks & preparations...
#   Missing 'xrd' values filled with 0.
#   'ipo_year' created from 'ipodate'.
#
# Constructing dependent variable...
#   OCF_Scaled_t_plus_1 created.
#
# Constructing Set A (OLS) predictors...
#   Set A predictors constructed.
#
# Constructing control dummy variables...
#   Dummy variables constructed.
#
# Constructing Set B (additional ML) predictors...
#   Set B predictors constructed.
#
# Selecting final model variables and dropping intermediate columns...
#   Shape of DataFrame after final column selection: (170598, 31)
#   Final columns kept: 31 columns
#
# Feature construction complete. Final DataFrame shape: (170598, 31)
#
# Starting final dropna. Initial rows: 170598, DataFrame shape: (170598, 31)
#   Rows dropped due to NaNs in critical model variables: 47149
#   Shape of analytical sample AFTER final dropna: (123449, 31)
#   Verification: No NaNs in checked columns of analytical sample.
#
# Starting annual winsorization for 22 columns...
#   Winsorizing column: Accruals_Scaled_t
#   Winsorizing column: CAPX_Scaled_t
#   Winsorizing column: CapitalIntensity_t
#   Winsorizing column: CurrentRatio_t
#   Winsorizing column: DP_Scaled_t
#   Winsorizing column: DebtToAssets_t
#   Winsorizing column: Delta_AP_Scaled_t
#   Winsorizing column: Delta_Inv_Scaled_t
#   Winsorizing column: Delta_Rec_Scaled_t
#   Winsorizing column: Delta_Sales_Scaled_t
#   Winsorizing column: GPM_t
#   Winsorizing column: InvTurnover_t
#   Winsorizing column: MkBk_t
#   Winsorizing column: NI_Scaled_Lag_t
#   Winsorizing column: NI_Scaled_t
#   Winsorizing column: OCF_Scaled_Lag_t
#   Winsorizing column: OCF_Scaled_t_plus_1
#   Winsorizing column: OCFtoSales_t
#   Winsorizing column: RecTurnover_t
#   Winsorizing column: XRD_Scaled_t
#   Winsorizing column: XSGA_Scaled_t
#   Winsorizing column: ln_at_t
# Annual winsorization complete.

# %%
# Split data chronologically - train on pre-2018, test on 2018+
train_df, test_df = processing.split_data_chronologically(df_final, 'fyear', split_year=2018)

print(f"Training data shape: {train_df.shape}")
print(f"Test data shape: {test_df.shape}")
print(f"Training period: {train_df['fyear'].min()} - {train_df['fyear'].max()}")
print(f"Test period: {test_df['fyear'].min()} - {test_df['fyear'].max()}")
# Out:
# Training set: 102567 obs (Predictor years <= 2018)
# Test set: 20882 obs (Predictor years > 2018)
# Training data shape: (102567, 31)
# Test data shape: (20882, 31)
# Training period: 2001.0 - 2018.0
# Test period: 2019.0 - 2022.0

# %%
# Set B (Additional ML) predictor feature names
SET_B_FEATURES = [
    'XSGA_Scaled_t', 'XRD_Scaled_t', 'CAPX_Scaled_t', 'CurrentRatio_t',
    'DebtToAssets_t', 'OCFtoSales_t', 'InvTurnover_t', 'RecTurnover_t',
    'GPM_t', 'Delta_Sales_Scaled_t', 'NI_Scaled_Lag_t',
    'CapitalIntensity_t', 'MkBk_t', 'FirmAge_t'
]

# Prepare features and dependent variable for XGBoost regression
# Using SET_A + SET_B features WITHOUT dummy controls for robustness test
X_train = train_df[lists.SET_A_FEATURES + lists.SET_B_FEATURES]
y_train = train_df[lists.DEPENDENT_VARIABLE]

X_test = test_df[lists.SET_A_FEATURES + lists.SET_B_FEATURES]
y_test = test_df[lists.DEPENDENT_VARIABLE]

print("Features included in the model:")
for i, feature in enumerate(X_train.columns, 1):
    print(f"{i:2d}. {feature}")

print(f"\nDependent variable: {lists.DEPENDENT_VARIABLE}")
print(f"Training observations: {len(X_train)}")
print(f"Test observations: {len(X_test)}")
# Out:
# Features included in the model:
#  1. OCF_Scaled_Lag_t
#  2. NI_Scaled_t
#  3. Accruals_Scaled_t
#  4. Delta_Rec_Scaled_t
#  5. Delta_Inv_Scaled_t
#  6. Delta_AP_Scaled_t
#  7. DP_Scaled_t
#  8. ln_at_t
#  9. XSGA_Scaled_t
# 10. XRD_Scaled_t
# 11. CAPX_Scaled_t
# 12. CurrentRatio_t
# 13. DebtToAssets_t
# 14. OCFtoSales_t
# 15. InvTurnover_t
# 16. RecTurnover_t
# 17. GPM_t
# 18. Delta_Sales_Scaled_t
# 19. NI_Scaled_Lag_t
# 20. CapitalIntensity_t
# 21. MkBk_t
# 22. FirmAge_t
# 23. ASC606_TCJA_combined_dummy
#
# Dependent variable: OCF_Scaled_t_plus_1
# Training observations: 102567
# Test observations: 20882

# %%
# =============================================================================
# BAYESIAN OPTIMIZATION FOR HYPERPARAMETER TUNING
# =============================================================================

import xgboost as xgb
from skopt import BayesSearchCV
from skopt.space import Real, Integer
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np
import time

# Define hyperparameter search space for Bayesian optimization
search_space = {
    'max_depth': Integer(3, 10),
    'learning_rate': Real(0.01, 0.2, prior='log-uniform'),
    'n_estimators': Integer(100, 300),
    'subsample': Real(0.8, 1.0),
    'colsample_bytree': Real(0.8, 1.0)
}

# Create XGBoost regressor
xgb_regressor = xgb.XGBRegressor(random_state=42, objective='reg:squarederror')

# Perform Bayesian Search with 5-fold cross-validation
print("Performing 5-fold cross-validation for XGBoost Bayesian hyperparameter tuning...")
print(f"Search space dimensions: {len(search_space)}")
print(f"Number of iterations: 100 (intelligent sampling)")

start_time = time.time()

bayes_search = BayesSearchCV(
    estimator=xgb_regressor,
    search_spaces=search_space,
    n_iter=100,  # Number of parameter settings to try
    cv=5,
    scoring='r2',
    n_jobs=-1,
    random_state=42,
    verbose=2  # Increased verbosity for more detailed progress information
)

# Fit the bayesian search
bayes_search.fit(X_train, y_train)

# Print best parameters and score
print(f"\nBest hyperparameters: {bayes_search.best_params_}")
print(f"Best cross-validation R² score: {bayes_search.best_score_:.4f}")
print(f"Standard deviation: {bayes_search.cv_results_['std_test_score'][bayes_search.best_index_]:.4f}")

elapsed_time = time.time() - start_time
print(f"Bayesian search completed in {elapsed_time:.2f} seconds")

# For compatibility with rest of the code, assign to grid_search variable
grid_search = bayes_search
# Out:
# Performing 5-fold cross-validation for XGBoost Bayesian hyperparameter tuning...
# Search space dimensions: 5
# Number of iterations: 100 (intelligent sampling)
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   8.2s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   8.5s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   8.5s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   8.6s
# [CV] END colsample_bytree=0.8820207917706628, learning_rate=0.08846938749167613, max_depth=10, n_estimators=163, subsample=0.9340295896537869; total time=   8.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   2.2s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   2.2s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   2.3s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   2.3s
# [CV] END colsample_bytree=0.9674776711106569, learning_rate=0.1410001814373689, max_depth=5, n_estimators=290, subsample=0.9728255830929902; total time=   1.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.2s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.2s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.2s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.2s
# [CV] END colsample_bytree=0.8889665024602303, learning_rate=0.15677815829096733, max_depth=4, n_estimators=187, subsample=0.8375910372734697; total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   4.8s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   4.8s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   4.8s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   4.6s
# [CV] END colsample_bytree=0.9624791976714727, learning_rate=0.0167343965754388, max_depth=7, n_estimators=261, subsample=0.9046104656108768; total time=   4.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   4.7s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   4.7s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   4.8s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   4.8s
# [CV] END colsample_bytree=0.9599106883214347, learning_rate=0.037144037621545944, max_depth=7, n_estimators=243, subsample=0.9807704145013374; total time=   4.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.1s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.1s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.2s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.1s
# [CV] END colsample_bytree=0.9468056035971137, learning_rate=0.16678162679202435, max_depth=4, n_estimators=138, subsample=0.9601006462913491; total time=   1.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   4.9s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   4.8s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   4.8s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   4.8s
# [CV] END colsample_bytree=0.9234158717004632, learning_rate=0.10204043807287104, max_depth=6, n_estimators=275, subsample=0.9185239350611136; total time=   4.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   4.2s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   4.3s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   4.3s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   4.2s
# [CV] END colsample_bytree=0.9086806135380625, learning_rate=0.15738364519796957, max_depth=6, n_estimators=268, subsample=0.8648119964568748; total time=   4.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  16.5s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  16.5s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  16.6s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  16.7s
# [CV] END colsample_bytree=0.9910955972619857, learning_rate=0.08156982208605644, max_depth=9, n_estimators=183, subsample=0.8762129529594986; total time=  16.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=  18.4s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=  18.4s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=  18.4s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=  18.5s
# [CV] END colsample_bytree=0.8007260614509487, learning_rate=0.11588344218319326, max_depth=8, n_estimators=151, subsample=0.915732867245677; total time=  18.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8615750714534475, learning_rate=0.02244228705785464, max_depth=5, n_estimators=115, subsample=0.9622075488737961; total time=   7.6s
# [CV] END colsample_bytree=0.8615750714534475, learning_rate=0.02244228705785464, max_depth=5, n_estimators=115, subsample=0.9622075488737961; total time=   7.7s
# [CV] END colsample_bytree=0.8615750714534475, learning_rate=0.02244228705785464, max_depth=5, n_estimators=115, subsample=0.9622075488737961; total time=   7.8s
# [CV] END colsample_bytree=0.8615750714534475, learning_rate=0.02244228705785464, max_depth=5, n_estimators=115, subsample=0.9622075488737961; total time=   7.8s
# [CV] END colsample_bytree=0.8615750714534475, learning_rate=0.02244228705785464, max_depth=5, n_estimators=115, subsample=0.9622075488737961; total time=   7.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.969253388582821, learning_rate=0.05810708520869151, max_depth=7, n_estimators=213, subsample=0.8588975108920802; total time=  19.3s[CV] END colsample_bytree=0.969253388582821, learning_rate=0.05810708520869151, max_depth=7, n_estimators=213, subsample=0.8588975108920802; total time=  19.3s
#
# [CV] END colsample_bytree=0.969253388582821, learning_rate=0.05810708520869151, max_depth=7, n_estimators=213, subsample=0.8588975108920802; total time=  19.2s
# [CV] END colsample_bytree=0.969253388582821, learning_rate=0.05810708520869151, max_depth=7, n_estimators=213, subsample=0.8588975108920802; total time=  19.4s
# [CV] END colsample_bytree=0.969253388582821, learning_rate=0.05810708520869151, max_depth=7, n_estimators=213, subsample=0.8588975108920802; total time=  19.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8346703713111856, learning_rate=0.021855240713009472, max_depth=8, n_estimators=228, subsample=0.9395608884675546; total time=  13.1s
# [CV] END colsample_bytree=0.8346703713111856, learning_rate=0.021855240713009472, max_depth=8, n_estimators=228, subsample=0.9395608884675546; total time=  13.4s
# [CV] END colsample_bytree=0.8346703713111856, learning_rate=0.021855240713009472, max_depth=8, n_estimators=228, subsample=0.9395608884675546; total time=  13.5s
# [CV] END colsample_bytree=0.8346703713111856, learning_rate=0.021855240713009472, max_depth=8, n_estimators=228, subsample=0.9395608884675546; total time=  13.6s
# [CV] END colsample_bytree=0.8346703713111856, learning_rate=0.021855240713009472, max_depth=8, n_estimators=228, subsample=0.9395608884675546; total time=  13.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9345965580666196, learning_rate=0.012198206607859764, max_depth=8, n_estimators=293, subsample=0.8; total time=  25.8s
# [CV] END colsample_bytree=0.9345965580666196, learning_rate=0.012198206607859764, max_depth=8, n_estimators=293, subsample=0.8; total time=  25.9s
# [CV] END colsample_bytree=0.9345965580666196, learning_rate=0.012198206607859764, max_depth=8, n_estimators=293, subsample=0.8; total time=  26.0s
# [CV] END colsample_bytree=0.9345965580666196, learning_rate=0.012198206607859764, max_depth=8, n_estimators=293, subsample=0.8; total time=  26.0s
# [CV] END colsample_bytree=0.9345965580666196, learning_rate=0.012198206607859764, max_depth=8, n_estimators=293, subsample=0.8; total time=  26.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9549711654829954, learning_rate=0.012770090753737062, max_depth=10, n_estimators=100, subsample=1.0; total time=  17.1s
# [CV] END colsample_bytree=0.9549711654829954, learning_rate=0.012770090753737062, max_depth=10, n_estimators=100, subsample=1.0; total time=  17.3s
# [CV] END colsample_bytree=0.9549711654829954, learning_rate=0.012770090753737062, max_depth=10, n_estimators=100, subsample=1.0; total time=  17.4s
# [CV] END colsample_bytree=0.9549711654829954, learning_rate=0.012770090753737062, max_depth=10, n_estimators=100, subsample=1.0; total time=  17.6s
# [CV] END colsample_bytree=0.9549711654829954, learning_rate=0.012770090753737062, max_depth=10, n_estimators=100, subsample=1.0; total time=  17.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.05565771349239923, max_depth=3, n_estimators=300, subsample=1.0; total time=   4.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05565771349239923, max_depth=3, n_estimators=300, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05565771349239923, max_depth=3, n_estimators=300, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05565771349239923, max_depth=3, n_estimators=300, subsample=1.0; total time=   4.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05565771349239923, max_depth=3, n_estimators=300, subsample=1.0; total time=   5.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8665510512881266, learning_rate=0.02578537822860331, max_depth=10, n_estimators=300, subsample=0.9512552189647514; total time=  42.9s
# [CV] END colsample_bytree=0.8665510512881266, learning_rate=0.02578537822860331, max_depth=10, n_estimators=300, subsample=0.9512552189647514; total time=  42.9s
# [CV] END colsample_bytree=0.8665510512881266, learning_rate=0.02578537822860331, max_depth=10, n_estimators=300, subsample=0.9512552189647514; total time=  43.3s
# [CV] END colsample_bytree=0.8665510512881266, learning_rate=0.02578537822860331, max_depth=10, n_estimators=300, subsample=0.9512552189647514; total time=  43.5s
# [CV] END colsample_bytree=0.8665510512881266, learning_rate=0.02578537822860331, max_depth=10, n_estimators=300, subsample=0.9512552189647514; total time=  43.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8191034085635361, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.973270206548333; total time=   3.5s
# [CV] END colsample_bytree=0.8191034085635361, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.973270206548333; total time=   3.6s
# [CV] END colsample_bytree=0.8191034085635361, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.973270206548333; total time=   3.6s
# [CV] END colsample_bytree=0.8191034085635361, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.973270206548333; total time=   3.6s
# [CV] END colsample_bytree=0.8191034085635361, learning_rate=0.01, max_depth=3, n_estimators=300, subsample=0.973270206548333; total time=   3.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.06069342757531337, max_depth=3, n_estimators=136, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.06069342757531337, max_depth=3, n_estimators=136, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.06069342757531337, max_depth=3, n_estimators=136, subsample=1.0; total time=   2.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.06069342757531337, max_depth=3, n_estimators=136, subsample=1.0; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.06069342757531337, max_depth=3, n_estimators=136, subsample=1.0; total time=   2.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8808342222150792, learning_rate=0.0303790042056328, max_depth=4, n_estimators=300, subsample=0.9114092669969597; total time=   4.7s
# [CV] END colsample_bytree=0.8808342222150792, learning_rate=0.0303790042056328, max_depth=4, n_estimators=300, subsample=0.9114092669969597; total time=   4.7s
# [CV] END colsample_bytree=0.8808342222150792, learning_rate=0.0303790042056328, max_depth=4, n_estimators=300, subsample=0.9114092669969597; total time=   4.7s
# [CV] END colsample_bytree=0.8808342222150792, learning_rate=0.0303790042056328, max_depth=4, n_estimators=300, subsample=0.9114092669969597; total time=   4.7s
# [CV] END colsample_bytree=0.8808342222150792, learning_rate=0.0303790042056328, max_depth=4, n_estimators=300, subsample=0.9114092669969597; total time=   4.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8341316451657621, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8448794256026468; total time=  11.7s
# [CV] END colsample_bytree=0.8341316451657621, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8448794256026468; total time=  11.8s
# [CV] END colsample_bytree=0.8341316451657621, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8448794256026468; total time=  11.8s
# [CV] END colsample_bytree=0.8341316451657621, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8448794256026468; total time=  11.9s
# [CV] END colsample_bytree=0.8341316451657621, learning_rate=0.01, max_depth=7, n_estimators=300, subsample=0.8448794256026468; total time=  12.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.03015252548874827, max_depth=7, n_estimators=300, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.03015252548874827, max_depth=7, n_estimators=300, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03015252548874827, max_depth=7, n_estimators=300, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03015252548874827, max_depth=7, n_estimators=300, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03015252548874827, max_depth=7, n_estimators=300, subsample=0.8; total time=  12.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.04821160063261006, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.04821160063261006, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.04821160063261006, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.04821160063261006, max_depth=5, n_estimators=300, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.04821160063261006, max_depth=5, n_estimators=300, subsample=0.8; total time=   7.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8867341441580991, learning_rate=0.02755858176263492, max_depth=3, n_estimators=203, subsample=0.8448440690432663; total time=   2.4s
# [CV] END colsample_bytree=0.8867341441580991, learning_rate=0.02755858176263492, max_depth=3, n_estimators=203, subsample=0.8448440690432663; total time=   2.5s
# [CV] END colsample_bytree=0.8867341441580991, learning_rate=0.02755858176263492, max_depth=3, n_estimators=203, subsample=0.8448440690432663; total time=   2.4s
# [CV] END colsample_bytree=0.8867341441580991, learning_rate=0.02755858176263492, max_depth=3, n_estimators=203, subsample=0.8448440690432663; total time=   2.4s
# [CV] END colsample_bytree=0.8867341441580991, learning_rate=0.02755858176263492, max_depth=3, n_estimators=203, subsample=0.8448440690432663; total time=   2.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.867857543556193, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.8071423057679253; total time=  33.9s
# [CV] END colsample_bytree=0.867857543556193, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.8071423057679253; total time=  34.2s
# [CV] END colsample_bytree=0.867857543556193, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.8071423057679253; total time=  34.4s
# [CV] END colsample_bytree=0.867857543556193, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.8071423057679253; total time=  34.5s
# [CV] END colsample_bytree=0.867857543556193, learning_rate=0.01, max_depth=10, n_estimators=300, subsample=0.8071423057679253; total time=  34.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9096779097713344, learning_rate=0.05530742660713429, max_depth=7, n_estimators=100, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.9096779097713344, learning_rate=0.05530742660713429, max_depth=7, n_estimators=100, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.9096779097713344, learning_rate=0.05530742660713429, max_depth=7, n_estimators=100, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.9096779097713344, learning_rate=0.05530742660713429, max_depth=7, n_estimators=100, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.9096779097713344, learning_rate=0.05530742660713429, max_depth=7, n_estimators=100, subsample=1.0; total time=   3.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9064694102129898, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8389124088339469; total time=   9.3s
# [CV] END colsample_bytree=0.9064694102129898, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8389124088339469; total time=   9.5s
# [CV] END colsample_bytree=0.9064694102129898, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8389124088339469; total time=   9.5s
# [CV] END colsample_bytree=0.9064694102129898, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8389124088339469; total time=   9.6s
# [CV] END colsample_bytree=0.9064694102129898, learning_rate=0.2, max_depth=10, n_estimators=100, subsample=0.8389124088339469; total time=   9.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.055926652904958934, max_depth=10, n_estimators=100, subsample=0.8; total time=   9.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.055926652904958934, max_depth=10, n_estimators=100, subsample=0.8; total time=   9.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.055926652904958934, max_depth=10, n_estimators=100, subsample=0.8; total time=   9.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.055926652904958934, max_depth=10, n_estimators=100, subsample=0.8; total time=   9.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.055926652904958934, max_depth=10, n_estimators=100, subsample=0.8; total time=   9.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.1162064857541829, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1162064857541829, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1162064857541829, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1162064857541829, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1162064857541829, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.017959083301537962, max_depth=7, n_estimators=300, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.017959083301537962, max_depth=7, n_estimators=300, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.017959083301537962, max_depth=7, n_estimators=300, subsample=1.0; total time=   9.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.017959083301537962, max_depth=7, n_estimators=300, subsample=1.0; total time=   9.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.017959083301537962, max_depth=7, n_estimators=300, subsample=1.0; total time=   9.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.060760222275021196, max_depth=10, n_estimators=300, subsample=1.0; total time=  26.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.060760222275021196, max_depth=10, n_estimators=300, subsample=1.0; total time=  27.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.060760222275021196, max_depth=10, n_estimators=300, subsample=1.0; total time=  27.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.060760222275021196, max_depth=10, n_estimators=300, subsample=1.0; total time=  27.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.060760222275021196, max_depth=10, n_estimators=300, subsample=1.0; total time=  27.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9621641441680183, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8205307280812293; total time=   1.0s
# [CV] END colsample_bytree=0.9621641441680183, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8205307280812293; total time=   1.1s
# [CV] END colsample_bytree=0.9621641441680183, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8205307280812293; total time=   1.1s
# [CV] END colsample_bytree=0.9621641441680183, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8205307280812293; total time=   1.1s
# [CV] END colsample_bytree=0.9621641441680183, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8205307280812293; total time=   1.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.03229461261190556, max_depth=7, n_estimators=133, subsample=0.8; total time=   5.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03229461261190556, max_depth=7, n_estimators=133, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03229461261190556, max_depth=7, n_estimators=133, subsample=0.8; total time=   5.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03229461261190556, max_depth=7, n_estimators=133, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.03229461261190556, max_depth=7, n_estimators=133, subsample=0.8; total time=   5.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8108468401635768, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.9699868946035737; total time=   2.8s
# [CV] END colsample_bytree=0.8108468401635768, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.9699868946035737; total time=   2.8s
# [CV] END colsample_bytree=0.8108468401635768, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.9699868946035737; total time=   2.8s
# [CV] END colsample_bytree=0.8108468401635768, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.9699868946035737; total time=   2.8s
# [CV] END colsample_bytree=0.8108468401635768, learning_rate=0.2, max_depth=3, n_estimators=300, subsample=0.9699868946035737; total time=   2.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.03733596160491698, max_depth=5, n_estimators=100, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03733596160491698, max_depth=5, n_estimators=100, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03733596160491698, max_depth=5, n_estimators=100, subsample=1.0; total time=   2.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03733596160491698, max_depth=5, n_estimators=100, subsample=1.0; total time=   2.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03733596160491698, max_depth=5, n_estimators=100, subsample=1.0; total time=   2.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.02458636597074392, max_depth=6, n_estimators=197, subsample=1.0; total time=   5.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.02458636597074392, max_depth=6, n_estimators=197, subsample=1.0; total time=   5.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.02458636597074392, max_depth=6, n_estimators=197, subsample=1.0; total time=   5.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.02458636597074392, max_depth=6, n_estimators=197, subsample=1.0; total time=   5.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.02458636597074392, max_depth=6, n_estimators=197, subsample=1.0; total time=   5.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.09870939949043696, max_depth=3, n_estimators=300, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.09870939949043696, max_depth=3, n_estimators=300, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.09870939949043696, max_depth=3, n_estimators=300, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.09870939949043696, max_depth=3, n_estimators=300, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.09870939949043696, max_depth=3, n_estimators=300, subsample=0.8; total time=   3.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.02791367700331733, max_depth=10, n_estimators=163, subsample=1.0; total time=  22.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.02791367700331733, max_depth=10, n_estimators=163, subsample=1.0; total time=  22.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.02791367700331733, max_depth=10, n_estimators=163, subsample=1.0; total time=  23.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.02791367700331733, max_depth=10, n_estimators=163, subsample=1.0; total time=  23.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.02791367700331733, max_depth=10, n_estimators=163, subsample=1.0; total time=  23.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9682242261851376, learning_rate=0.0846744594752656, max_depth=3, n_estimators=202, subsample=0.981542185880691; total time=   2.6s
# [CV] END colsample_bytree=0.9682242261851376, learning_rate=0.0846744594752656, max_depth=3, n_estimators=202, subsample=0.981542185880691; total time=   2.7s
# [CV] END colsample_bytree=0.9682242261851376, learning_rate=0.0846744594752656, max_depth=3, n_estimators=202, subsample=0.981542185880691; total time=   2.7s
# [CV] END colsample_bytree=0.9682242261851376, learning_rate=0.0846744594752656, max_depth=3, n_estimators=202, subsample=0.981542185880691; total time=   2.6s
# [CV] END colsample_bytree=0.9682242261851376, learning_rate=0.0846744594752656, max_depth=3, n_estimators=202, subsample=0.981542185880691; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.01599733788681158, max_depth=9, n_estimators=265, subsample=1.0; total time=  20.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01599733788681158, max_depth=9, n_estimators=265, subsample=1.0; total time=  20.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01599733788681158, max_depth=9, n_estimators=265, subsample=1.0; total time=  20.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01599733788681158, max_depth=9, n_estimators=265, subsample=1.0; total time=  20.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01599733788681158, max_depth=9, n_estimators=265, subsample=1.0; total time=  20.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  34.2s
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  34.2s
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  34.4s
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  34.4s
# [CV] END colsample_bytree=0.8409858565244097, learning_rate=0.17450826417478574, max_depth=10, n_estimators=300, subsample=0.8637687250145709; total time=  34.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.018102869325113322, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.018102869325113322, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.018102869325113322, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.018102869325113322, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.018102869325113322, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.036718159426696206, max_depth=10, n_estimators=246, subsample=0.8; total time=  22.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.036718159426696206, max_depth=10, n_estimators=246, subsample=0.8; total time=  23.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.036718159426696206, max_depth=10, n_estimators=246, subsample=0.8; total time=  23.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.036718159426696206, max_depth=10, n_estimators=246, subsample=0.8; total time=  23.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.036718159426696206, max_depth=10, n_estimators=246, subsample=0.8; total time=  23.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.022363260333620117, max_depth=7, n_estimators=255, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.022363260333620117, max_depth=7, n_estimators=255, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.022363260333620117, max_depth=7, n_estimators=255, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.022363260333620117, max_depth=7, n_estimators=255, subsample=0.8; total time=   7.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.022363260333620117, max_depth=7, n_estimators=255, subsample=0.8; total time=   7.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.014208381861195482, max_depth=7, n_estimators=300, subsample=0.8; total time=  10.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.014208381861195482, max_depth=7, n_estimators=300, subsample=0.8; total time=  11.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.014208381861195482, max_depth=7, n_estimators=300, subsample=0.8; total time=  11.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.014208381861195482, max_depth=7, n_estimators=300, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.014208381861195482, max_depth=7, n_estimators=300, subsample=0.8; total time=  11.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9975452606710054, learning_rate=0.09681821306993549, max_depth=6, n_estimators=101, subsample=0.8419195572735998; total time=   2.0s
# [CV] END colsample_bytree=0.9975452606710054, learning_rate=0.09681821306993549, max_depth=6, n_estimators=101, subsample=0.8419195572735998; total time=   2.1s
# [CV] END colsample_bytree=0.9975452606710054, learning_rate=0.09681821306993549, max_depth=6, n_estimators=101, subsample=0.8419195572735998; total time=   2.1s
# [CV] END colsample_bytree=0.9975452606710054, learning_rate=0.09681821306993549, max_depth=6, n_estimators=101, subsample=0.8419195572735998; total time=   2.1s
# [CV] END colsample_bytree=0.9975452606710054, learning_rate=0.09681821306993549, max_depth=6, n_estimators=101, subsample=0.8419195572735998; total time=   2.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=1.0, learning_rate=0.021556178158624418, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.021556178158624418, max_depth=3, n_estimators=300, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.021556178158624418, max_depth=3, n_estimators=300, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.021556178158624418, max_depth=3, n_estimators=300, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.021556178158624418, max_depth=3, n_estimators=300, subsample=0.8; total time=   3.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8220803831652476, learning_rate=0.042889009195610825, max_depth=5, n_estimators=198, subsample=0.8059624326472927; total time=   3.0s
# [CV] END colsample_bytree=0.8220803831652476, learning_rate=0.042889009195610825, max_depth=5, n_estimators=198, subsample=0.8059624326472927; total time=   3.0s
# [CV] END colsample_bytree=0.8220803831652476, learning_rate=0.042889009195610825, max_depth=5, n_estimators=198, subsample=0.8059624326472927; total time=   3.0s
# [CV] END colsample_bytree=0.8220803831652476, learning_rate=0.042889009195610825, max_depth=5, n_estimators=198, subsample=0.8059624326472927; total time=   3.0s
# [CV] END colsample_bytree=0.8220803831652476, learning_rate=0.042889009195610825, max_depth=5, n_estimators=198, subsample=0.8059624326472927; total time=   3.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.033195014040481224, max_depth=6, n_estimators=157, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.033195014040481224, max_depth=6, n_estimators=157, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.033195014040481224, max_depth=6, n_estimators=157, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.033195014040481224, max_depth=6, n_estimators=157, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.033195014040481224, max_depth=6, n_estimators=157, subsample=0.8; total time=   3.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8171405305497337, learning_rate=0.07355659609734691, max_depth=5, n_estimators=159, subsample=0.8756925453804545; total time=   2.6s
# [CV] END colsample_bytree=0.8171405305497337, learning_rate=0.07355659609734691, max_depth=5, n_estimators=159, subsample=0.8756925453804545; total time=   2.6s
# [CV] END colsample_bytree=0.8171405305497337, learning_rate=0.07355659609734691, max_depth=5, n_estimators=159, subsample=0.8756925453804545; total time=   2.6s
# [CV] END colsample_bytree=0.8171405305497337, learning_rate=0.07355659609734691, max_depth=5, n_estimators=159, subsample=0.8756925453804545; total time=   2.6s
# [CV] END colsample_bytree=0.8171405305497337, learning_rate=0.07355659609734691, max_depth=5, n_estimators=159, subsample=0.8756925453804545; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8121347247874056, learning_rate=0.06885247756894305, max_depth=4, n_estimators=239, subsample=0.9751075785758305; total time=   2.7s
# [CV] END colsample_bytree=0.8121347247874056, learning_rate=0.06885247756894305, max_depth=4, n_estimators=239, subsample=0.9751075785758305; total time=   2.7s
# [CV] END colsample_bytree=0.8121347247874056, learning_rate=0.06885247756894305, max_depth=4, n_estimators=239, subsample=0.9751075785758305; total time=   2.8s
# [CV] END colsample_bytree=0.8121347247874056, learning_rate=0.06885247756894305, max_depth=4, n_estimators=239, subsample=0.9751075785758305; total time=   2.8s
# [CV] END colsample_bytree=0.8121347247874056, learning_rate=0.06885247756894305, max_depth=4, n_estimators=239, subsample=0.9751075785758305; total time=   2.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.030162517071170722, max_depth=5, n_estimators=258, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.030162517071170722, max_depth=5, n_estimators=258, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.030162517071170722, max_depth=5, n_estimators=258, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.030162517071170722, max_depth=5, n_estimators=258, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.030162517071170722, max_depth=5, n_estimators=258, subsample=0.8; total time=   4.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8706873877066497, learning_rate=0.015211090512910893, max_depth=7, n_estimators=181, subsample=0.8035787137171677; total time=   6.8s
# [CV] END colsample_bytree=0.8706873877066497, learning_rate=0.015211090512910893, max_depth=7, n_estimators=181, subsample=0.8035787137171677; total time=   6.8s
# [CV] END colsample_bytree=0.8706873877066497, learning_rate=0.015211090512910893, max_depth=7, n_estimators=181, subsample=0.8035787137171677; total time=   6.9s
# [CV] END colsample_bytree=0.8706873877066497, learning_rate=0.015211090512910893, max_depth=7, n_estimators=181, subsample=0.8035787137171677; total time=   6.8s
# [CV] END colsample_bytree=0.8706873877066497, learning_rate=0.015211090512910893, max_depth=7, n_estimators=181, subsample=0.8035787137171677; total time=   6.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8346171998241678, learning_rate=0.19233529682443565, max_depth=6, n_estimators=104, subsample=0.9852205028341363; total time=   2.0s
# [CV] END colsample_bytree=0.8346171998241678, learning_rate=0.19233529682443565, max_depth=6, n_estimators=104, subsample=0.9852205028341363; total time=   2.0s
# [CV] END colsample_bytree=0.8346171998241678, learning_rate=0.19233529682443565, max_depth=6, n_estimators=104, subsample=0.9852205028341363; total time=   2.0s
# [CV] END colsample_bytree=0.8346171998241678, learning_rate=0.19233529682443565, max_depth=6, n_estimators=104, subsample=0.9852205028341363; total time=   2.1s
# [CV] END colsample_bytree=0.8346171998241678, learning_rate=0.19233529682443565, max_depth=6, n_estimators=104, subsample=0.9852205028341363; total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8115341152648943, learning_rate=0.05478469660212315, max_depth=8, n_estimators=297, subsample=0.827783165042995; total time=  12.5s
# [CV] END colsample_bytree=0.8115341152648943, learning_rate=0.05478469660212315, max_depth=8, n_estimators=297, subsample=0.827783165042995; total time=  12.6s
# [CV] END colsample_bytree=0.8115341152648943, learning_rate=0.05478469660212315, max_depth=8, n_estimators=297, subsample=0.827783165042995; total time=  12.7s
# [CV] END colsample_bytree=0.8115341152648943, learning_rate=0.05478469660212315, max_depth=8, n_estimators=297, subsample=0.827783165042995; total time=  12.8s
# [CV] END colsample_bytree=0.8115341152648943, learning_rate=0.05478469660212315, max_depth=8, n_estimators=297, subsample=0.827783165042995; total time=  12.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.061661277556618516, max_depth=5, n_estimators=100, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.061661277556618516, max_depth=5, n_estimators=100, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.061661277556618516, max_depth=5, n_estimators=100, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.061661277556618516, max_depth=5, n_estimators=100, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.061661277556618516, max_depth=5, n_estimators=100, subsample=0.8; total time=   1.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.015351683259157261, max_depth=7, n_estimators=260, subsample=0.8; total time=   8.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.015351683259157261, max_depth=7, n_estimators=260, subsample=0.8; total time=   8.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.015351683259157261, max_depth=7, n_estimators=260, subsample=0.8; total time=   8.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.015351683259157261, max_depth=7, n_estimators=260, subsample=0.8; total time=   8.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.015351683259157261, max_depth=7, n_estimators=260, subsample=0.8; total time=   8.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.04149042527435814, max_depth=4, n_estimators=238, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.04149042527435814, max_depth=4, n_estimators=238, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.04149042527435814, max_depth=4, n_estimators=238, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.04149042527435814, max_depth=4, n_estimators=238, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.04149042527435814, max_depth=4, n_estimators=238, subsample=0.8; total time=   2.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.025470242007106143, max_depth=5, n_estimators=300, subsample=0.8; total time=   4.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.025470242007106143, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.025470242007106143, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.025470242007106143, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.025470242007106143, max_depth=5, n_estimators=300, subsample=0.8; total time=   5.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.02768518035689941, max_depth=5, n_estimators=300, subsample=1.0; total time=   4.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.02768518035689941, max_depth=5, n_estimators=300, subsample=1.0; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.02768518035689941, max_depth=5, n_estimators=300, subsample=1.0; total time=   4.7s
# ...
# [CV] END colsample_bytree=0.8, learning_rate=0.022427411040793082, max_depth=7, n_estimators=198, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.022427411040793082, max_depth=7, n_estimators=198, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.022427411040793082, max_depth=7, n_estimators=198, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.022427411040793082, max_depth=7, n_estimators=198, subsample=0.8; total time=   6.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.027720172166424598, max_depth=8, n_estimators=179, subsample=0.8; total time=   7.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.027720172166424598, max_depth=8, n_estimators=179, subsample=0.8; total time=   7.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.027720172166424598, max_depth=8, n_estimators=179, subsample=0.8; total time=   7.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.027720172166424598, max_depth=8, n_estimators=179, subsample=0.8; total time=   8.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.027720172166424598, max_depth=8, n_estimators=179, subsample=0.8; total time=   8.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8095093642482759, learning_rate=0.017062443493736524, max_depth=5, n_estimators=230, subsample=0.9702253095460099; total time=   3.9s
# [CV] END colsample_bytree=0.8095093642482759, learning_rate=0.017062443493736524, max_depth=5, n_estimators=230, subsample=0.9702253095460099; total time=   3.9s
# [CV] END colsample_bytree=0.8095093642482759, learning_rate=0.017062443493736524, max_depth=5, n_estimators=230, subsample=0.9702253095460099; total time=   3.9s
# [CV] END colsample_bytree=0.8095093642482759, learning_rate=0.017062443493736524, max_depth=5, n_estimators=230, subsample=0.9702253095460099; total time=   4.0s
# [CV] END colsample_bytree=0.8095093642482759, learning_rate=0.017062443493736524, max_depth=5, n_estimators=230, subsample=0.9702253095460099; total time=   4.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9596308146466598, learning_rate=0.01030061963848492, max_depth=5, n_estimators=299, subsample=0.9913124301437859; total time=   5.3s
# [CV] END colsample_bytree=0.9596308146466598, learning_rate=0.01030061963848492, max_depth=5, n_estimators=299, subsample=0.9913124301437859; total time=   5.3s
# [CV] END colsample_bytree=0.9596308146466598, learning_rate=0.01030061963848492, max_depth=5, n_estimators=299, subsample=0.9913124301437859; total time=   5.5s
# [CV] END colsample_bytree=0.9596308146466598, learning_rate=0.01030061963848492, max_depth=5, n_estimators=299, subsample=0.9913124301437859; total time=   5.4s
# [CV] END colsample_bytree=0.9596308146466598, learning_rate=0.01030061963848492, max_depth=5, n_estimators=299, subsample=0.9913124301437859; total time=   5.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8116021672637588, learning_rate=0.013724983582533727, max_depth=10, n_estimators=231, subsample=0.8101679225957827; total time=  25.2s
# [CV] END colsample_bytree=0.8116021672637588, learning_rate=0.013724983582533727, max_depth=10, n_estimators=231, subsample=0.8101679225957827; total time=  25.2s
# [CV] END colsample_bytree=0.8116021672637588, learning_rate=0.013724983582533727, max_depth=10, n_estimators=231, subsample=0.8101679225957827; total time=  25.5s
# [CV] END colsample_bytree=0.8116021672637588, learning_rate=0.013724983582533727, max_depth=10, n_estimators=231, subsample=0.8101679225957827; total time=  25.5s
# [CV] END colsample_bytree=0.8116021672637588, learning_rate=0.013724983582533727, max_depth=10, n_estimators=231, subsample=0.8101679225957827; total time=  25.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8050645738838759, learning_rate=0.04836551792266213, max_depth=6, n_estimators=138, subsample=0.9937879818732953; total time=   2.9s
# [CV] END colsample_bytree=0.8050645738838759, learning_rate=0.04836551792266213, max_depth=6, n_estimators=138, subsample=0.9937879818732953; total time=   2.9s
# [CV] END colsample_bytree=0.8050645738838759, learning_rate=0.04836551792266213, max_depth=6, n_estimators=138, subsample=0.9937879818732953; total time=   3.0s
# [CV] END colsample_bytree=0.8050645738838759, learning_rate=0.04836551792266213, max_depth=6, n_estimators=138, subsample=0.9937879818732953; total time=   3.0s
# [CV] END colsample_bytree=0.8050645738838759, learning_rate=0.04836551792266213, max_depth=6, n_estimators=138, subsample=0.9937879818732953; total time=   3.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8127412964127104, learning_rate=0.024861884029505923, max_depth=7, n_estimators=119, subsample=0.9988681721752088; total time=   4.2s
# [CV] END colsample_bytree=0.8127412964127104, learning_rate=0.024861884029505923, max_depth=7, n_estimators=119, subsample=0.9988681721752088; total time=   4.3s
# [CV] END colsample_bytree=0.8127412964127104, learning_rate=0.024861884029505923, max_depth=7, n_estimators=119, subsample=0.9988681721752088; total time=   4.3s
# [CV] END colsample_bytree=0.8127412964127104, learning_rate=0.024861884029505923, max_depth=7, n_estimators=119, subsample=0.9988681721752088; total time=   4.4s
# [CV] END colsample_bytree=0.8127412964127104, learning_rate=0.024861884029505923, max_depth=7, n_estimators=119, subsample=0.9988681721752088; total time=   4.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.017592188018228972, max_depth=6, n_estimators=269, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.017592188018228972, max_depth=6, n_estimators=269, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.017592188018228972, max_depth=6, n_estimators=269, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.017592188018228972, max_depth=6, n_estimators=269, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.017592188018228972, max_depth=6, n_estimators=269, subsample=0.8; total time=   6.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.020951818461716464, max_depth=6, n_estimators=259, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.020951818461716464, max_depth=6, n_estimators=259, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.020951818461716464, max_depth=6, n_estimators=259, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.020951818461716464, max_depth=6, n_estimators=259, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.020951818461716464, max_depth=6, n_estimators=259, subsample=0.8; total time=   5.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8128755819471946, learning_rate=0.07459970188632312, max_depth=4, n_estimators=300, subsample=0.9423762572167589; total time=   3.3s
# [CV] END colsample_bytree=0.8128755819471946, learning_rate=0.07459970188632312, max_depth=4, n_estimators=300, subsample=0.9423762572167589; total time=   3.3s
# [CV] END colsample_bytree=0.8128755819471946, learning_rate=0.07459970188632312, max_depth=4, n_estimators=300, subsample=0.9423762572167589; total time=   3.3s
# [CV] END colsample_bytree=0.8128755819471946, learning_rate=0.07459970188632312, max_depth=4, n_estimators=300, subsample=0.9423762572167589; total time=   3.3s
# [CV] END colsample_bytree=0.8128755819471946, learning_rate=0.07459970188632312, max_depth=4, n_estimators=300, subsample=0.9423762572167589; total time=   3.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.017577961732088344, max_depth=8, n_estimators=227, subsample=0.8; total time=  10.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.017577961732088344, max_depth=8, n_estimators=227, subsample=0.8; total time=  10.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.017577961732088344, max_depth=8, n_estimators=227, subsample=0.8; total time=  11.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.017577961732088344, max_depth=8, n_estimators=227, subsample=0.8; total time=  11.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.017577961732088344, max_depth=8, n_estimators=227, subsample=0.8; total time=  11.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9958483810232838, learning_rate=0.04464301648713742, max_depth=4, n_estimators=186, subsample=0.9933368693537084; total time=   2.0s
# [CV] END colsample_bytree=0.9958483810232838, learning_rate=0.04464301648713742, max_depth=4, n_estimators=186, subsample=0.9933368693537084; total time=   2.0s
# [CV] END colsample_bytree=0.9958483810232838, learning_rate=0.04464301648713742, max_depth=4, n_estimators=186, subsample=0.9933368693537084; total time=   2.0s
# [CV] END colsample_bytree=0.9958483810232838, learning_rate=0.04464301648713742, max_depth=4, n_estimators=186, subsample=0.9933368693537084; total time=   2.1s
# [CV] END colsample_bytree=0.9958483810232838, learning_rate=0.04464301648713742, max_depth=4, n_estimators=186, subsample=0.9933368693537084; total time=   2.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.021034481777236796, max_depth=6, n_estimators=265, subsample=0.8; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.021034481777236796, max_depth=6, n_estimators=265, subsample=0.8; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.021034481777236796, max_depth=6, n_estimators=265, subsample=0.8; total time=   5.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.021034481777236796, max_depth=6, n_estimators=265, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.021034481777236796, max_depth=6, n_estimators=265, subsample=0.8; total time=   5.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.016366005356320348, max_depth=6, n_estimators=283, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.016366005356320348, max_depth=6, n_estimators=283, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.016366005356320348, max_depth=6, n_estimators=283, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.016366005356320348, max_depth=6, n_estimators=283, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.016366005356320348, max_depth=6, n_estimators=283, subsample=0.8; total time=   6.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   0.9s
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   0.9s
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   0.9s
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   0.9s
# [CV] END colsample_bytree=0.9626941261884042, learning_rate=0.03416834069898455, max_depth=3, n_estimators=101, subsample=0.8112882083350075; total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8126286900549418, learning_rate=0.03678476480022252, max_depth=7, n_estimators=103, subsample=0.8470059969305858; total time=   3.5s
# [CV] END colsample_bytree=0.8126286900549418, learning_rate=0.03678476480022252, max_depth=7, n_estimators=103, subsample=0.8470059969305858; total time=   3.6s
# [CV] END colsample_bytree=0.8126286900549418, learning_rate=0.03678476480022252, max_depth=7, n_estimators=103, subsample=0.8470059969305858; total time=   3.7s
# [CV] END colsample_bytree=0.8126286900549418, learning_rate=0.03678476480022252, max_depth=7, n_estimators=103, subsample=0.8470059969305858; total time=   3.6s
# [CV] END colsample_bytree=0.8126286900549418, learning_rate=0.03678476480022252, max_depth=7, n_estimators=103, subsample=0.8470059969305858; total time=   3.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9999701562358352, learning_rate=0.043729236745335735, max_depth=10, n_estimators=295, subsample=0.82394609975037; total time=  30.2s
# [CV] END colsample_bytree=0.9999701562358352, learning_rate=0.043729236745335735, max_depth=10, n_estimators=295, subsample=0.82394609975037; total time=  30.5s
# [CV] END colsample_bytree=0.9999701562358352, learning_rate=0.043729236745335735, max_depth=10, n_estimators=295, subsample=0.82394609975037; total time=  30.6s
# [CV] END colsample_bytree=0.9999701562358352, learning_rate=0.043729236745335735, max_depth=10, n_estimators=295, subsample=0.82394609975037; total time=  30.8s
# [CV] END colsample_bytree=0.9999701562358352, learning_rate=0.043729236745335735, max_depth=10, n_estimators=295, subsample=0.82394609975037; total time=  30.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.021652464280797458, max_depth=5, n_estimators=267, subsample=0.8; total time=   4.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.021652464280797458, max_depth=5, n_estimators=267, subsample=0.8; total time=   4.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.021652464280797458, max_depth=5, n_estimators=267, subsample=0.8; total time=   4.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.021652464280797458, max_depth=5, n_estimators=267, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.021652464280797458, max_depth=5, n_estimators=267, subsample=0.8; total time=   4.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.018616690549108802, max_depth=6, n_estimators=248, subsample=0.8; total time=   5.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.018616690549108802, max_depth=6, n_estimators=248, subsample=0.8; total time=   5.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.018616690549108802, max_depth=6, n_estimators=248, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.018616690549108802, max_depth=6, n_estimators=248, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.018616690549108802, max_depth=6, n_estimators=248, subsample=0.8; total time=   5.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.021998461043987373, max_depth=6, n_estimators=276, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.021998461043987373, max_depth=6, n_estimators=276, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.021998461043987373, max_depth=6, n_estimators=276, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.021998461043987373, max_depth=6, n_estimators=276, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.021998461043987373, max_depth=6, n_estimators=276, subsample=0.8; total time=   6.3s
#
# Best hyperparameters: OrderedDict({'colsample_bytree': 0.8, 'learning_rate': 0.02484110362529456, 'max_depth': 7, 'n_estimators': 189, 'subsample': 0.8})
# Best cross-validation R² score: 0.6973
# Standard deviation: 0.0290
# Bayesian search completed in 1088.60 seconds

# %%
# =============================================================================
# XGBOOST MODEL EVALUATION - SET A + SET B FEATURES
# =============================================================================

# Use the optimized model from grid search
best_xgb_model = grid_search.best_estimator_

# Generate predictions using the optimized model
y_train_pred = best_xgb_model.predict(X_train)
y_test_pred = best_xgb_model.predict(X_test)

# Performance evaluation function for model metrics
def print_model_performance(y_true, y_pred, model_name, dataset):
    """
    Calculate and display performance metrics for regression models.
    
    Parameters:
    - y_true: actual values
    - y_pred: predicted values
    - model_name: model name for display
    - dataset: dataset name (Train/Test)
    """
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    print(f"{model_name} ({dataset}): R²={r2:.4f} | RMSE={rmse:.4f} | MAE={mae:.4f}")

# Display XGBoost performance results with extended feature set
print("XGBOOST PERFORMANCE (SET A + SET B FEATURES - NO DUMMIES):")
print_model_performance(y_train, y_train_pred, "XGBoost", "Train")
print_model_performance(y_test, y_test_pred, "XGBoost", "Test")
# Out:
# XGBOOST PERFORMANCE (SET A + SET B FEATURES):
# XGBoost (Train): R²=0.8393 | RMSE=0.4248 | MAE=0.1511
# XGBoost (Test): R²=0.6484 | RMSE=0.5783 | MAE=0.1971

# %%
# =============================================================================
# FEATURE IMPORTANCE ANALYSIS
# =============================================================================

import pandas as pd

# Get feature importances
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': best_xgb_model.feature_importances_
}).sort_values('importance', ascending=False)

print("FEATURE IMPORTANCE RANKING (SET A + SET B FEATURES - NO DUMMIES):")
print("="*50)
for i, (_, row) in enumerate(feature_importance.iterrows(), 1):
    print(f"{i:2d}. {row['feature']:<25} {row['importance']:.4f}")

# Print model details
print(f"\nMODEL DETAILS:")
print(f"Max Depth: {best_xgb_model.max_depth}")
print(f"Learning Rate: {best_xgb_model.learning_rate}")
print(f"N Estimators: {best_xgb_model.n_estimators}")
print(f"Subsample: {best_xgb_model.subsample}")
print(f"Colsample Bytree: {best_xgb_model.colsample_bytree}")
print(f"Number of Features: {best_xgb_model.n_features_in_}")
# Out:
# FEATURE IMPORTANCE RANKING (SET A + SET B FEATURES):
# ==================================================
#  1. ln_at_t                   0.3135
#  2. DebtToAssets_t            0.1378
#  3. OCF_Scaled_Lag_t          0.0939
#  4. NI_Scaled_t               0.0465
#  5. ASC606_TCJA_combined_dummy 0.0450
#  6. OCFtoSales_t              0.0418
#  7. XRD_Scaled_t              0.0356
#  8. MkBk_t                    0.0268
#  9. CurrentRatio_t            0.0258
# 10. NI_Scaled_Lag_t           0.0243
# 11. XSGA_Scaled_t             0.0214
# 12. InvTurnover_t             0.0195
# 13. Delta_Rec_Scaled_t        0.0180
# 14. CapitalIntensity_t        0.0174
# 15. RecTurnover_t             0.0166
# 16. Delta_Sales_Scaled_t      0.0160
# 17. Delta_AP_Scaled_t         0.0159
# 18. FirmAge_t                 0.0150
# 19. DP_Scaled_t               0.0150
# 20. Accruals_Scaled_t         0.0147
# 21. GPM_t                     0.0142
# 22. CAPX_Scaled_t             0.0127
# 23. Delta_Inv_Scaled_t        0.0125
#
# MODEL DETAILS:
# Max Depth: 7
# Learning Rate: 0.02484110362529456
# N Estimators: 189
# Subsample: 0.8
# Colsample Bytree: 0.8
# Number of Features: 23
